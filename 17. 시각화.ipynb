# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib 
import seaborn

# %%
# 한글폰트 검색
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim') !=-1:
        print(i.name)
# Out:
# New Gulim
# Gulim

# %%
# 한글 폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt
plt.title('클래스와 오브젝트')
plt.xlabel('클래스')
plt.ylabel('오브젝트')
# Out:
# Text(0, 0.5, '오브젝트')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe['dataset'].unique() #범주형 변수
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

# %%
d1.shape, d2.shape, d3.shape, d4.shape
# Out:
# ((11, 3), (11, 3), (11, 3), (11, 3))

# %%
d1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
d2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
d3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
d4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
plt.plot(d1['x'],d1['y'],'o')

# %%
plt.plot(d2['x'],d2['y'],'o')

# %%
plt.plot(d3['x'],d3['y'],'o')

# %%
plt.plot(d4['x'],d4['y'],'o')

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %%
plt.figure(figsize = (10,6))
plt.title('5일간 주식 가격')
plt.plot(dates, prices)

# %%
plt.figure(figsize = (10,6))
plt.title('Stock Prices Over 5 Days')

# Axis title
plt.xlabel('Date')
plt.ylabel('Price')

#  y range
plt.ylim(95, 110)

# Grid
plt.grid()

# Plots (coordinates)
plt.plot(dates, prices, marker='o', label='Stock Price', color='blue')

# Upper right corner stock price
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(dates, prices)
plt.title('Stick Prices - Subplot 1')
plt.xticks(rotation = 40)

plt.subplot(1,2,2)
plt.bar(dates, prices)
plt.title('Stick Prices - Subplot 2')
plt.xticks(rotation = 40)

plt.savefig('my_stock_price_chart.png')

# %%
import numpy as np
data = np.arange(10)
plt.plot(data)

# %%
import numpy as np
data = np.random.randn(50).cumsum()
plt.plot(data)

# %%
# 1변량 차트, 뱐수의 값을 요약 => 분포 분석 목적

plt.hist(np.random.randn(100),bins=20, color='r')
# Out:
# (array([ 1.,  1.,  0.,  1.,  3.,  1.,  9.,  6.,  9., 16.,  8., 10., 11.,
#          9.,  8.,  1.,  1.,  2.,  0.,  3.]),
#  array([-2.79581232, -2.51350056, -2.2311888 , -1.94887704, -1.66656528,
#         -1.38425352, -1.10194176, -0.81962999, -0.53731823, -0.25500647,
#          0.02730529,  0.30961705,  0.59192881,  0.87424057,  1.15655234,
#          1.4388641 ,  1.72117586,  2.00348762,  2.28579938,  2.56811114,
#          2.8504229 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.subplot(1,3,1)
plt.plot(dates, prices)
plt.title('Stick Prices - Subplot 1')
plt.xticks(rotation = 40)

plt.subplot(1,3,2)
plt.bar(dates, prices)
plt.title('Stick Prices - Subplot 2')
plt.xticks(rotation = 40)

plt.subplot(1,3,3)
plt.hist(np.random.randn(100),bins=20, color='r')


plt.savefig('my_stock_price_chart.png')

# %% [markdown]
# # 새로운 dataset

# %%
import seaborn as sns
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 1변량 그래프: Histogram
lt.hist(data=tips_df, x='total_bill', bins = 20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %%
fig = plt.figure(figsize = (12,5))
axes1 = fig.add_subplot (1,2,1) #1행 2열의 첫번째 차트 #total_bill
axes2 = fig.add_subplot(1,2,2) # tips
axes1.hist(data = tips_df, x = 'total_bill', bins = 20)
axes2.hist(data = tips_df, x = 'tip', bins = 20)
plt.tight_layout()
plt.show()

# %%
# Boxplot
fig = plt.figure(figsize = (12,5))
axes = fig.add_subplot (1,1,1) #total_bill
axes.boxplot(data = tips_df, x = 'total_bill') # x값 하나로 그려서 1변량 차트
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
axes = fig.add_subplot (1,1,1) #total_bill
axes.boxplot(
    x = [
        tips_df [tips_df ['sex'] == 'Female']['total_bill'],
        tips_df [tips_df ['sex'] == 'Male']['total_bill']
    ],
    labels = ['Female', 'Male']
)
plt.title('여자 vs 남자 팁')
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
axes1 = fig.add_subplot (1,1,1) #total_bill
axes1.boxplot(
    x = [
        tips_df [tips_df ['smoker'] == 'No']['tip'],
        tips_df [tips_df ['smoker'] == 'Yes']['tip']
    ],
    labels = ['Non-smoker', 'Smoker']
)
plt.title('흡연자 vs 비흡연자 팁')
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
axes2 = fig.add_subplot (1,1,1) #total_bill
axes2.boxplot(
    x = [
        tips_df [tips_df ['time'] == 'Lunch']['tip'],
        tips_df [tips_df ['time'] == 'Dinner']['tip']
    ],
    labels = ['Lunch', 'Dinner']
)
plt.title('시간대별 팁')
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
axes3 = fig.add_subplot (1,1,1) #total_bill
axes3.boxplot(
    x = [
        tips_df [tips_df ['day'] == 'Thur']['tip'],
        tips_df [tips_df ['day'] == 'Fri']['tip'],
        tips_df [tips_df ['day'] == 'Sat']['tip'],
        tips_df [tips_df ['day'] == 'Sun']['tip']
    ],
    labels = ['Thur', 'Fri','Sat','Sun']
)
plt.title('요일별 팁')
plt.show()

# %%
fig = plt.figure(figsize = (12,5))
axes4 = fig.add_subplot (1,1,1) #total_bill
axes4.boxplot(
    x = [
        tips_df [tips_df ['time'] == 'Lunch']['total_bill'],
        tips_df [tips_df ['time'] == 'Dinner']['total_bill']
    ],
    labels = ['Lunch', 'Dinner']
)
plt.title('시간대별 총금액')
plt.show()

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %% [markdown]
# # Scatter, 산점도

# %%
fig = plt.figure()
axes4 = fig.add_subplot (1,1,1) #total_bill
axes4.scatter(
    tips_df ['total_bill'], tips_df ['tip']
)
plt.show()

# %% [markdown]
# # 다변량 표현
# - 성별에 따라 - 색상 다르게 함
# - 값의 크기에 따라 - 점의 크기 다르게 함

# %%
colors = {'Female': '#875ab3','Male':'#ff9f9f'} # 16진 색상코드
tips_df ['tip_pct'] = tips_df ['tip'] / tips_df ['total_bill']

fig = plt.figure()
axes = fig.add_subplot (1,1,1) #total_bill
axes.scatter(
    tips_df ['total_bill'], tips_df ['tip'],
    s = tips_df ['size']*100, #table size
    c = tips_df ['sex'].map(colors),
    alpha = 0.5
)
plt.show()

# %%
fig = plt.figure()
axes = fig.add_subplot (1,1,1) #total_bill
axes.scatter(
    tips_df ['total_bill'], tips_df ['tip'],
    s = tips_df ['tip']**2*10, #tip
    c = tips_df ['sex'].map(colors),
    alpha = 0.5
)
plt.show()

# %%
# Pie chart: 비율
# 성별 비율 비교
sex_counts = tips_df ['sex'].value_counts()

fig = plt.figure()
axes = fig.add_subplot (1,1,1) 
axes.pie(
    sex_counts,
    colors = ['#875ab3', '#ff9f9f'],
    labels = sex_counts.index,
    autopct = '%1.1f%%',
    startangle = 90
)
plt.show()
