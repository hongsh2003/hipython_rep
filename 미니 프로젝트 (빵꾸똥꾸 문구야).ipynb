# %% [markdown]
# # Trial

# %%
print('='*44)
space=' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호":<6} {"제품명":<12} {"가격":>10}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000 },
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    #print(i+1,m)
    print(f'{i+1:<9}{m['name']:<13}{m['price']:>10}원')

print('-'*44)

ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
qty = int(input('주문할 수량 입력: '))
total = qty*menu[ord_num]['price']
menut = menu[ord_num]['name']

print(f'주문하신 메뉴는 {menut}입니다. 결제하실 금액은 {total:,}원')
print('-'*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호     제품명                  가격
# --------------------------------------------
# 1        샤프                 6000원
# 2        볼펜                 3000원
# 3        지우개                1000원
# 4        화이트                3000원
# 5        공책                 3500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      21     print(f'{i+1:<9}{m['name']:<13}{m['price']:>10}원')
#      23 print('-'*44)
# ---> 25 ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
#      26 qty = int(input('주문할 수량 입력: '))
#      27 total = qty*menu[ord_num]['price']
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================

# %%
print('='*44)
phone=input('고객님의 전화번호를 입력해 주세요:')

user_id=f'user_{phone[-4:]}'

point=500

print('='*44)
print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
print('='*44)
# Out:
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 print('='*44)
# ----> 2 phone=input('고객님의 전화번호를 입력해 주세요:')
#       4 user_id=f'user_{phone[-4:]}'
#       6 point=500
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
store_name = '빵꾸똥꾸 문구야'
print(f'\t{store_name}\n\t에 오신 것을 환영합니다!')
print('='*44)

print(f'{"번호":<5} {"제품명":<10} {"가격":>6}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000 },
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

# 내용출력
for i, m in enumerate(menu):
    
    
    print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')

print('-'*44)

ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
qty = int(input('주문할 수량 입력: '))
total = qty*menu[ord_num]['price']
menut = menu[ord_num]['name']

print(f'주문하신 메뉴는 {menut}입니다. 결제하실 금액은 {total:,}원')
print('-'*44)
# Out:
# ============================================
# 	빵꾸똥꾸 문구야
# 	에 오신 것을 환영합니다!
# ============================================
# 번호    제품명            가격
# --------------------------------------------
# 1     샤프          6,000원
# 2     볼펜          3,000원
# 3     지우개         1,000원
# 4     화이트         3,000원
# 5     공책          3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 25
#      21     print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')
#      23 print('-'*44)
# ---> 25 ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
#      26 qty = int(input('주문할 수량 입력: '))
#      27 total = qty*menu[ord_num]['price']
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
space=' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호":<5} {"제품명":<10} {"가격":>6}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000 },
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

# 내용출력
for i, m in enumerate(menu):
    print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')

print('-'*44)

ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
qty = int(input('주문할 수량 입력: '))
total = qty*menu[ord_num]['price']
menut = menu[ord_num]['name']

print('-'*44)



print('='*44)
print(f'\t고객님이 선택하신 제품은\n\t{menut}입니다. \n\t몇 개를 드릴까요?\n')
qty = int(input('\t수량을 숫자로 입력하세요: '))
print('='*44)



print('\n' + '=' * 44)
print(f'{"고객님이 선택하신 제품은":^25}')

print(f'\t{menut}{qty}개입니다')


a = input('더 주문하시겠습니다? (y/n)')
if a =='n':
    print(f'주문하신 금액은 {total}입니다')
    input('포인트를 적립하시겠습니까? (y/n)')
    
print('=' * 44)



print('='*44)
phone=input('전화번호를 입력해 주세요:')

user_id=f'user_{phone[-4:]}'

point=500

print('='*44)
print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
print('='*44)



print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호    제품명            가격
# --------------------------------------------
# 1     샤프          6,000원
# 2     볼펜          3,000원
# 3     지우개         1,000원
# 4     화이트         3,000원
# 5     공책          3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      21     print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')
#      23 print('-'*44)
# ---> 25 ord_num = int(input('주문하실 제품 번호를 선택하세요'))-1
#      26 qty = int(input('주문할 수량 입력: '))
#      27 total = qty*menu[ord_num]['price']
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
space=' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호":<5} {"제품명":<10} {"가격":>6}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000 },
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

# 메뉴 출력
for i, m in enumerate(menu):
    print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')

print('-'*44)

# 주문 입력
ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
menut = menu[ord_num]['name']

print('='*44)
print(f'\t고객님이 선택하신 제품은\n\t{menut}입니다. \n\t몇 개를 드릴까요?\n')
qty = int(input('\t수량을 숫자로 입력하세요: '))
total = qty * menu[ord_num]['price']
print('='*44)

# 확인 및 추가 주문 여부
print('\n' + '=' * 44)
print(f'{"고객님이 선택하신 제품은":^37}')
print(f'\t{menut} {qty}개입니다')

a = input('더 주문하시겠습니까? (y/n): ')
if a.lower() == 'n':
    print(f'\n주문하신 금액은 {total:,}원입니다')
    input('포인트를 적립하시겠습니까? (y/n): ')

# 고객정보 및 포인트
print('='*44)
phone = input('전화번호를 입력해 주세요: ')
user_id = f'user_{phone[-4:]}'
point = 500
print('='*44)
print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
print('='*44)

# 결제 완료 화면
print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호    제품명            가격
# --------------------------------------------
# 1     샤프          6,000원
# 2     볼펜          3,000원
# 3     지우개         1,000원
# 4     화이트         3,000원
# 5     공책          3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 26
#      23 print('-'*44)
#      25 # 주문 입력
# ---> 26 ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
#      27 menut = menu[ord_num]['name']
#      29 print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
space=' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호":<5} {"제품명":<10} {"가격":>6}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000 },
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

# 메뉴 출력
for i, m in enumerate(menu):
    print(f'{i+1:<5} {m["name"]:<10} {m["price"]:>6,}원')

print('-'*44)

# 주문 입력
ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
menut = menu[ord_num]['name']

print('='*44)
print(f'\t고객님이 선택하신 제품은\n\t{menut}입니다. \n\t몇 개를 드릴까요?\n')
qty = int(input('\t수량을 숫자로 입력하세요: '))
total = qty * menu[ord_num]['price']

# 확인 및 추가 주문 여부
print('='*44)
print(f'{"고객님이 선택하신 제품은":^37}')
print(f'\t{menut} {qty}개입니다')

a = input('더 주문하시겠습니까? (y/n): ')

if a.lower() == 'n':
    print(f'\n주문하신 금액은 {total:,}원입니다')
    print('='*44)
    input('포인트를 적립하시겠습니까? (y/n): ')

# 고객정보 및 포인트
print('='*44)
phone = input('전화번호를 입력해 주세요: ')
user_id = f'user_{phone[-4:]}'
point = 500
print('='*44)
print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
print('='*44)

# 결제 완료 화면
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호    제품명            가격
# --------------------------------------------
# 1     샤프          6,000원
# 2     볼펜          3,000원
# 3     지우개         1,000원
# 4     화이트         3,000원
# 5     공책          3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 26
#      23 print('-'*44)
#      25 # 주문 입력
# ---> 26 ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
#      27 menut = menu[ord_num]['name']
#      29 print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Ver 2 (가격 예뻐진 ver)

# %%
print('='*44)
space = ' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
print('-'*44)

# 다중 주문 저장 리스트
order_list = []

while True:
    ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
    menut = menu[ord_num]['name']
    print('='*44)
    print(f'{"고객님이 선택하신 제품은":^33}')
    print(f'{menut + "입니다.":^33}')
    print(f'{"몇 개를 드릴까요?":^33}')
    qty = int(input('\t수량을 숫자로 입력하세요: '))
    
    order_list.append({
        'name': menut,
        'qty': qty,
        'price': menu[ord_num]['price']
    })

    a = input('더 주문하시겠습니까? (y/n): ')
    if a.lower() == 'n':
        break
    print('-'*44)

# 총액 계산 및 주문 출력
print('='*44)
print(f'\t\t{"주문 내역"}')
total = 0
print('-'*44)
for order in order_list:
    item_total = order['qty'] * order['price']
    total += item_total
    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

print('-'*44)
print(f'총 결제 금액: {total:,}원')
print('='*44)

# 포인트 적립
if input('포인트를 적립하시겠습니까? (y/n): ').lower() == 'y':
    phone = input('전화번호를 입력해 주세요: ')
    user_id = f'user_{phone[-4:]}'
    point = 500
    print('='*44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  2
# ============================================
#           고객님이 선택하신 제품은
#              볼펜입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  5
# ============================================
#           고객님이 선택하신 제품은
#              공책입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  10
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 볼펜	3개	-	9000원
# 공책	10개	-	35000원
# --------------------------------------------
# 총 결제 금액: 44,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  1234
# ============================================
# user_1234 고객님의 적립포인트는 500점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================

# %% [markdown]
# # 실험

# %%
print('='*44)
space = ' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호"}\t{"제품명"}\t\t\t{"가격"}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    print(f'{i+1}\t{m["name"]}\t\t\t{m["price"]}원')
print('-'*44)

# 다중 주문 저장 리스트
order_list = []

while True:
    ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
    menut = menu[ord_num]['name']
    print('='*44)
    print(f'{"고객님이 선택하신 제품은":^33}')
    print(f'{menut + "입니다.":^33}')
    print(f'{"몇 개를 드릴까요?":^33}')
    qty = int(input('\t수량을 숫자로 입력하세요: '))
    
    order_list.append({
        'name': menut,
        'qty': qty,
        'price': menu[ord_num]['price']
    })

    a = input('더 주문하시겠습니까? (y/n): ')
    if a.lower() == 'n':
        break
    print('-'*44)

# 총액 계산 및 주문 출력
print('='*44)
print(f'\t\t{"주문 내역"}')
total = 0
print('-'*44)
for order in order_list:
    item_total = order['qty'] * order['price']
    total += item_total
    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

print('-'*44)
print(f'총 결제 금액: {total:,}원')
print('='*44)

# 포인트 적립
if input('포인트를 적립하시겠습니까? (y/n): ').lower() == 'y':
    phone = input('전화번호를 입력해 주세요: ')
    user_id = f'user_{phone[-4:]}'
    point = 500
    print('='*44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호	제품명			가격
# --------------------------------------------
# 1	샤프			6000원
# 2	볼펜			3000원
# 3	지우개			1000원
# 4	화이트			3000원
# 5	공책			3500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      24 order_list = []
#      26 while True:
# ---> 27     ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
#      28     menut = menu[ord_num]['name']
#      29     print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('='*44)
space = ' '*7
store_name = '빵꾸똥꾸 문구야'
print(f'\t{space}{store_name}')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
print('-'*44)

menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
print('-'*44)

# 다중 주문 저장 리스트
order_list = []

while True:
    ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
    menut = menu[ord_num]['name']
    print('='*44)
    print(f'{"고객님이 선택하신 제품은":^33}')
    print(f'{menut + "입니다.":^33}')
    print(f'{"몇 개를 드릴까요?":^33}')
    qty = int(input('\t수량을 숫자로 입력하세요: '))
    
    order_list.append({
        'name': menut,
        'qty': qty,
        'price': menu[ord_num]['price']
    })

    a = input('더 주문하시겠습니까? (y/n): ')
    if a.lower() == 'n':
        break
    print('-'*44)

# 총액 계산 및 주문 출력
print('='*44)
print(f'\t\t{"주문 내역"}')
total = 0
print('-'*44)
for order in order_list:
    item_total = order['qty'] * order['price']
    total += item_total
    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

print('-'*44)
print(f'총 결제 금액: {total:,}원')
print('='*44)

# 포인트 적립
if input('포인트를 적립하시겠습니까? (y/n): ').lower() == 'y':
    phone = input('전화번호를 입력해 주세요: ')
    user_id = f'user_{phone[-4:]}'
    point = int(total * 0.05)   #포인트는 총금액의 5%
    print('='*44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#              지우개입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  2
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	2개	-	2000원
# --------------------------------------------
# 총 결제 금액: 2,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  235
# ============================================
# user_235 고객님의 적립포인트는 100점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================

# %% [markdown]
# # Ver 3 (같은거 여러번 주문하면 합쳐지는 ver)

# %%
print('='*44)
space = ' '*7
print(f'\t{space}빵꾸똥꾸 문구야')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('='*44)

print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
print('-'*44)

# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
print('-'*44)

# 다중 주문 저장 리스트
order_list = []

while True:
    ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
    menut = menu[ord_num]['name']

    print('='*44)
    print(f'{"고객님이 선택하신 제품은":^33}')
    print(f'{menut + " 입니다.":^33}')
    print(f'{"몇 개를 드릴까요?":^33}')

    qty = int(input('\t수량을 숫자로 입력하세요: '))

    # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
    flag = True
    for i in range(len(order_list)):
        if order_list[i]['name'] == menu[ord_num]["name"]:
            order_list[i]['qty'] += qty
            flag = False
            break

    # 새로운 거 주문 하면 append
    if flag:
        order_list.append({
            'name': menut,
            'qty': qty,
            'price': menu[ord_num]['price']
        })

    a = input('더 주문하시겠습니까? (y/n): ')
    if a.lower() == 'n':
        break
    print('-'*44)

# 총액 계산 및 주문 출력
total = 0

print('='*44)
print(f'\t\t{"주문 내역"}')
print('-'*44)

for order in order_list:
    item_total = order['qty'] * order['price']
    total += item_total

    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

print('-'*44)
print(f'총 결제 금액: {total:,}원')
print('='*44)

# 포인트 적립
if input('포인트를 적립하시겠습니까? (y/n): ').lower() == 'y':
    
    phone = input('전화번호를 입력해 주세요: ')
    user_id = f'user_{phone[-4:]}'
    point = int(total * 0.05)

    print('='*44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ============================================
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ============================================
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	6개	-	6000원
# --------------------------------------------
# 총 결제 금액: 6,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  1235
# ============================================
# user_1235 고객님의 적립포인트는 300점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================

# %%
space = ' '*7


# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]
while True:
		print('╔' + '═' * 40 + '╗')
		print(f'\t{space}빵꾸똥꾸 문구야')
		print(f'{"에 오신 것을 환영합니다!":>25}')
		print('╚' + '═' * 40 + '╝')
		
		
		print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
		print('-'*44)
		
		for i, m in enumerate(menu):
		    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
		print('-'*44)
		
		# 다중 주문 저장 리스트
		order_list = []
		
		while True:
		    try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
		        ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
		        if not (0 <= ord_num < len(menu)): 
		            print('='*44)
		            print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
		            print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
		            print('='*44)
		            continue 
		    except ValueError:  
		        print('='*44)
		        print(f'{"[알림] 잘못된 입력입니다.":^44}')
		        print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
		        print('='*44)
		        continue 
		    
		    menut = menu[ord_num]['name']
		
		    print('='*44)
		    print(f'{"고객님이 선택하신 제품은":^33}')
		    print(f'{menut + " 입니다.":^33}')
		    print(f'{"몇 개를 드릴까요?":^33}')
		    
		    while True: ### 수량값 음수 및 문자 입력 방지 ###
		        try:
		            qty = int(input('\t수량을 숫자로 입력하세요: '))
		            if qty <=0:
		                print('='*44)
		                print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
		                print('='*44)
		                continue
		            break
		        except ValueError:
		            print('='*44)
		            print(f'{"[알림]숫자로만 입력해주세요.":^44}')
		            print('='*44)
		             
		    # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
		    flag = True
		    for i in range(len(order_list)):
		        if order_list[i]['name'] == menu[ord_num]["name"]:
		            order_list[i]['qty'] += qty
		            flag = False
		            break
		
		    # 새로운 거 주문 하면 append
		    if flag:
		        order_list.append({
		            'name': menut,
		            'qty': qty,
		            'price': menu[ord_num]['price']
		        })
		
		    a = input('더 주문하시겠습니까? (y/n): ')
		        # y/n 입력 유효성 검사
		    while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
		        print('='*44)
		        print(f'{"[알림] 잘못된 입력입니다.":^44}')
		        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
		        print('='*44)
		        a = input('더 주문하시겠습니까? (y/n): ')
		        
		    if a.lower() == 'n':
		        break
		    print('-'*44)
		
		# 총액 계산 및 주문 출력
		total = 0
		
		print('='*44)
		print(f'\t\t{"주문 내역"}')
		print('-'*44)
		
		for order in order_list:
		    item_total = order['qty'] * order['price']
		    total += item_total
		
		    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')
		
		print('-'*44)
		print(f'총 결제 금액: {total:,}원')
		print('='*44)
		
		# 포인트 적립 여부 y/n 유효성 검사
		ab = input('포인트를 적립하시겠습니까? (y/n): ')
		while ab.lower() not in ['y', 'n']:
		    print('=' * 44)
		    print(f'{"[알림] 잘못된 입력입니다.":^44}')
		    print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
		    print('=' * 44)
		    ab = input('포인트를 적립하시겠습니까? (y/n): ')
		
		# 'y'일 경우 포인트 적립
		if ab.lower() == 'y':
		    phone = input('전화번호를 입력해 주세요: ')
		    user_id = f'user_{phone[-4:]}'
		    point = int(total * 0.05)
		
		    print('=' * 44)
		    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
		
		print('='*44)
		print(f'{"결제가 완료되었습니다.":^37}')
		print(f'{"잠시만 기다려주세요.":^37}')
		print(f'{"감사합니다.":^40}')
		
		ab = input('더 주문 하시겠습니까? n
        ')
		
		if ab == 'y':
				continue
		else:
				print("안녕히 가세요 :)")
				break
		
		print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  4
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
# 	수량을 숫자로 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 화이트	3개	-	9000원
# --------------------------------------------
# 총 결제 금액: 9,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# 더 주문 하시겠습니까? (y/n): n
# 안녕히 가세요 :)

# %%
space = ' '*7


# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]
while True:
		print('╔' + '═' * 40 + '╗')
		print(f'\t{space}빵꾸똥꾸 문구야')
		print(f'{"에 오신 것을 환영합니다!":>25}')
		print('╚' + '═' * 40 + '╝')
		
		
		print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
		print('-'*44)
		
		for i, m in enumerate(menu):
		    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
		print('-'*44)
		
		while True:
				# 다중 주문 저장 리스트
				order_list = []
		    try: #제품번호 범위 및 숫자 외 입력 방지 
		        ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
		        if not (0 <= ord_num < len(menu)): 
		            print('='*44)
		            print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
		            print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
		            print('='*44)
		            continue 
		    except ValueError:  
		        print('='*44)
		        print(f'{"[알림] 잘못된 입력입니다.":^44}')
		        print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
		        print('='*44)
		        continue 
		    
		    menut = menu[ord_num]['name']
		
		    print('='*44)
		    print(f'{"고객님이 선택하신 제품은":^33}')
		    print(f'{menut + " 입니다.":^33}')
		    print(f'{"몇 개를 드릴까요?":^33}')
		    print("취소를 원하시면 숫자를 제외한 아무 입력을 해주세요")
		    
		    while True: #수량값 음수 및 문자 입력 방지 
		        try:
		            qty = int(input('\t수량을 숫자로 입력하세요: '))
		            if qty <=0:
		                print('='*44)
		                print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
		                print('='*44)
		                continue
		            break
		        except ValueError:
		            print('='*44)
		            print(f'{"[알림]숫자로만 입력해주세요.":^44}')
		            print('='*44)
		    
		    # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 
		    flag = True
		    for i in range(len(order_list)):
		        if order_list[i]['name'] == menu[ord_num]["name"]:
		            order_list[i]['qty'] += qty
		            flag = False
		            break
		
		    # 새로운 거 주문 하면 append
		    if flag:
		        order_list.append({
		            'name': menut,
		            'qty': qty,
		            'price': menu[ord_num]['price']
		        })
		
		    a = input('더 주문하시겠습니까? (y/n): ')
		        # y/n 입력 유효성 검사
		    while a.lower() not in ['y', 'n']: # y,n 외 입력 방지 
		        print('='*44)
		        print(f'{"[알림] 잘못된 입력입니다.":^44}')
		        print(f'{"[알림] \'y\' 또는 \'n\'으로만 입력해 주세요.":^44}')
		        print('='*44)
		        a = input('더 주문하시겠습니까? (y/n): ')
		        
		    if a.lower() == 'n':
		        break
		    print('-'*44)
		
		# 총액 계산 및 주문 출력
		total = 0
		
		print('='*44)
		print(f'\t\t{"주문 내역"}')
		print('-'*44)
		
		for order in order_list:
		    item_total = order['qty'] * order['price']
		    total += item_total
		
		    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')
		
		print('-'*44)
		print(f'총 결제 금액: {total:,}원')
		print('='*44)
		
		# 포인트 적립 여부 y/n 유효성 검사
		ab = input('포인트를 적립하시겠습니까? (y/n): ')
		while ab.lower() not in ['y', 'n']:
		    print('=' * 44)
		    print(f'{"[알림] 잘못된 입력입니다.":^44}')
		    print(f'{"[알림] \'y\' 또는 \'n\'으로만 입력해 주세요.":^44}')
		    print('=' * 44)
		    ab = input('포인트를 적립하시겠습니까? (y/n): ')
		
		# 'y'일 경우 포인트 적립
		if ab.lower() == 'y':
		    phone = input('전화번호를 입력해 주세요: ')
    
    # 전화번호가 숫자가 아닐 경우 재입력 요구
    while not phone.isdigit():
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^44}')
        print('=' * 44)
        phone = input('전화번호를 다시 입력해 주세요: ')

    user_id = f'user_{phone[-4:]}'
    point = int(total * 0.05)

    print('=' * 44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')
		
		print('='*44)
		print(f'{"결제가 완료되었습니다.":^37}')
		print(f'{"잠시만 기다려주세요.":^37}')
		print(f'{"감사합니다.":^40}')
		
		ab = input('더 주문 하시겠습니까? (y/n):')
		
		if ab == 'y':
				continue
		else:
				print("안녕히 가세요 :)")
				break
		
		print('='*44)
# Out:
#   File <string>:29
#     try: #제품번호 범위 및 숫자 외 입력 방지
#                                ^
# IndentationError: unindent does not match any outer indentation level

# %%
space = ' '*7
print('╔' + '═' * 40 + '╗')
print(f'\t{space}빵꾸똥꾸 문구야')
print(f'{"에 오신 것을 환영합니다!":>25}')
print('╚' + '═' * 40 + '╝')


print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
print('-'*44)

# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

for i, m in enumerate(menu):
    print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
print('-'*44)

# 다중 주문 저장 리스트
order_list = []

while True:
    try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
        ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
        if not (0 <= ord_num < len(menu)): 
            print('='*44)
            print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":<5}')
            print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":<30}')
            print('='*44)
            continue 
    except ValueError:  
        print('='*44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^37}')
        print('='*44)
        continue 
    
    menut = menu[ord_num]['name']

    print('='*44)
    print(f'{"고객님이 선택하신 제품은":^33}')
    print(f'{menut + " 입니다.":^33}')
    print(f'{"몇 개를 드릴까요?":^33}')
    
    while True: ### 수량값 음수 및 문자 입력 방지 ###
        try:
            qty = int(input('\t수량을 숫자로 입력하세요: '))
            if qty <=0:
                print('='*44)
                print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
                print('='*44)
                continue
            break
        except ValueError:
            print('='*44)
            print(f'{"[알림]숫자로만 입력해주세요.":^44}')
            print('='*44)
             
    # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
    flag = True
    for i in range(len(order_list)):
        if order_list[i]['name'] == menu[ord_num]["name"]:
            order_list[i]['qty'] += qty
            flag = False
            break

    # 새로운 거 주문 하면 append
    if flag:
        order_list.append({
            'name': menut,
            'qty': qty,
            'price': menu[ord_num]['price']
        })

    a = input('더 주문하시겠습니까? (y/n): ')
        # y/n 입력 유효성 검사
    while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
        print('='*44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
        print('='*44)
        a = input('더 주문하시겠습니까? (y/n): ')
        
    if a.lower() == 'n':
        break
    print('-'*44)

# 총액 계산 및 주문 출력
total = 0

print('='*44)
print(f'\t\t{"주문 내역"}')
print('-'*44)

for order in order_list:
    item_total = order['qty'] * order['price']
    total += item_total

    print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

print('-'*44)
print(f'총 결제 금액: {total:,}원')
print('='*44)

# 포인트 적립 여부 y/n 유효성 검사
ab = input('포인트를 적립하시겠습니까? (y/n): ')
while ab.lower() not in ['y', 'n']:
    print('=' * 44)
    print(f'{"[알림] 잘못된 입력입니다.":^44}')
    print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
    print('=' * 44)
    ab = input('포인트를 적립하시겠습니까? (y/n): ')

# 'y'일 경우 포인트 적립
if ab.lower() == 'y':
    phone = input('전화번호를 입력해 주세요: ')
    
    # 전화번호가 숫자가 아닐 경우 재입력 요구
    while not phone.isdigit():
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":<30}')
        print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":<30}')
        print('=' * 44)
        phone = input('전화번호를 다시 입력해 주세요: ')

    user_id = f'user_{phone[-4:]}'
    point = int(total * 0.05)

    print('=' * 44)
    print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

print('='*44)
print(f'{"결제가 완료되었습니다.":^37}')
print(f'{"잠시만 기다려주세요.":^37}')
print(f'{"감사합니다.":^40}')
print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  d
# ============================================
#           [알림] 잘못된 입력입니다.
#       [알림] 제품 번호를 숫자로 입력해 주세요.
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 29
#      27 while True:
#      28     try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 29         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
#      30         if not (0 <= ord_num < len(menu)):
#      31             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = input('주문하실 제품 번호를 선택하세요: ')

            print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')

            if ord_num == 'x':
                break
            else:
                ord_num = int(ord_num)

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요: ')
                if qty == 'x':
                    break
                else:
                    qty = int(qty)

                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
#     [알림] 주문 취소를 원하시면 x를 입력하세요.
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
#     [알림] 주문 취소를 원하시면 x를 입력하세요.
# 	수량을 입력하세요:  x
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 131
#     129 for order in order_list:
#     130     item_total = order['qty'] * order['price']
# --> 131     total += item_total
#     133     print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')
#     135 print('-'*44)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)


    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
                print('='*44)
                continue 
        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:
                qty = input('\t수량을 입력하세요: ')
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
                    print('='*44)
                    continue
                break
            except ValueError:
                print('='*44)
                print(f'{"[알림]숫자로만 입력해주세요.":^44}')
                print('='*44)

            if qty == 'x':
                break
            else:
                qty = int(qty)
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
            print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break
        
        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^44}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 55
#      53 try:
#      54     qty = input('\t수량을 입력하세요: ')
# ---> 55     if qty <=0:
#      56         print('='*44)
#      57         print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
# 문구점 주문 시스템 (콘솔용)

menu = [
    {'name': '샤프', 'price': 6000},
    {'name': '볼펜', 'price': 3000},
    {'name': '지우개', 'price': 1000},
    {'name': '화이트', 'price': 3000},
    {'name': '공책', 'price': 3500}
]

while True:
    order_list = []  # 주문 누적 리스트

    space = ' ' * 7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')

    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-' * 44)

    for i, m in enumerate(menu):
        print(f'{i + 1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-' * 44)

    while True:
        ord_input = input('주문하실 제품 번호를 선택하세요: ')
        if not ord_input.isdigit():
            print("[알림] 숫자로 입력해 주세요.")
            continue

        ord_num = int(ord_input) - 1
        if not (0 <= ord_num < len(menu)):
            print("[알림] 메뉴에 없는 제품 번호입니다.")
            continue

        menut = menu[ord_num]['name']
        print(f'고객님이 선택하신 제품은 {menut} 입니다.')

        while True:
            qty_input = input('수량을 입력하세요 (x:취소): ')
            if qty_input.lower() == 'x':
                break
            if not qty_input.isdigit() or int(qty_input) <= 0:
                print("[알림] 수량은 1 이상 숫자로 입력해주세요.")
                continue
            qty = int(qty_input)
            break
        else:
            continue

        # 중복 제품 수량 증가
        for item in order_list:
            if item['name'] == menut:
                item['qty'] += qty
                break
        else:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        more = input('더 주문하시겠습니까? (y/n): ')
        if more.lower() == 'n':
            break

    if not order_list:
        print("[알림] 주문이 없습니다. 초기 화면으로 돌아갑니다.")
        continue

    total = 0
    print('=' * 44)
    print('\t\t주문 내역')
    print('-' * 44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total
        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-' * 44)
    print(f'총 결제 금액: {total:,}원')
    print('=' * 44)

    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    while ab.lower() not in ['y', 'n']:
        ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")

    if ab.lower() == 'y':
        phone = input('전화번호를 입력해주세요: ')
        while not phone.isdigit():
            phone = input("[알림] 숫자만 입력해주세요: ")

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('=' * 44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"감사합니다. 다음에 또 오세요!":^37}')
    print('=' * 44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3\
# [알림] 숫자로 입력해 주세요.
# 주문하실 제품 번호를 선택하세요:  3
# 고객님이 선택하신 제품은 지우개 입니다.
# 수량을 입력하세요 (x:취소):  x
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	1개	-	1000원
# --------------------------------------------
# 총 결제 금액: 1,000원
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 87
#      84 print(f'총 결제 금액: {total:,}원')
#      85 print('=' * 44)
# ---> 87 ab = input('포인트를 적립하시겠습니까? (y/n): ')
#      88 while ab.lower() not in ['y', 'n']:
#      89     ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 문구점 주문 시스템 (콘솔용)

menu = [
    {'name': '샤프', 'price': 6000},
    {'name': '볼펜', 'price': 3000},
    {'name': '지우개', 'price': 1000},
    {'name': '화이트', 'price': 3000},
    {'name': '공책', 'price': 3500}
]

while True:
    order_list = []  # 주문 누적 리스트

    space = ' ' * 7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')

    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-' * 44)

    for i, m in enumerate(menu):
        print(f'{i + 1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-' * 44)

    while True:
        ord_input = input('주문하실 제품 번호를 선택하세요 (x:취소): ')
        if ord_input.lower() == 'x':
            order_list = []  # 주문 초기화
            break  # 시작화면으로 돌아감
        if not ord_input.isdigit():
            print("[알림] 숫자로 입력해 주세요.")
            continue

        ord_num = int(ord_input) - 1
        if not (0 <= ord_num < len(menu)):
            print("[알림] 메뉴에 없는 제품 번호입니다.")
            continue

        menut = menu[ord_num]['name']
        print(f'고객님이 선택하신 제품은 {menut} 입니다.')

        while True:
            qty_input = input('수량을 입력하세요 (x:취소): ')
            if qty_input.lower() == 'x':
                order_list = []  # 주문 초기화
                break  # 시작화면으로 돌아감
            if not qty_input.isdigit() or int(qty_input) <= 0:
                print("[알림] 수량은 1 이상 숫자로 입력해주세요.")
                continue
            qty = int(qty_input)
            break
        else:
            continue

        # 중복 제품 수량 증가
        for item in order_list:
            if item['name'] == menut:
                item['qty'] += qty
                break
        else:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        more = input('더 주문하시겠습니까? (y/n): ')
        if more.lower() == 'n':
            break

    if not order_list:
        print("[알림] 주문이 없습니다. 초기 화면으로 돌아갑니다.")
        continue

    total = 0
    print('=' * 44)
    print('\t\t주문 내역')
    print('-' * 44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total
        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-' * 44)
    print(f'총 결제 금액: {total:,}원')
    print('=' * 44)

    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    while ab.lower() not in ['y', 'n']:
        ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")

    if ab.lower() == 'y':
        phone = input('전화번호를 입력해주세요: ')
        while not phone.isdigit():
            phone = input("[알림] 숫자만 입력해주세요: ")

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('=' * 44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"감사합니다. 다음에 또 오세요!":^37}')
    print('=' * 44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요 (x:취소):  ㄹ
# [알림] 숫자로 입력해 주세요.
# 주문하실 제품 번호를 선택하세요 (x:취소):  3
# 고객님이 선택하신 제품은 지우개 입니다.
# 수량을 입력하세요 (x:취소):  x
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	1개	-	1000원
# --------------------------------------------
# 총 결제 금액: 1,000원
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 91
#      88 print(f'총 결제 금액: {total:,}원')
#      89 print('=' * 44)
# ---> 91 ab = input('포인트를 적립하시겠습니까? (y/n): ')
#      92 while ab.lower() not in ['y', 'n']:
#      93     ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: '))

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^44}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^44}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 화이트	3개	-	9000원
# --------------------------------------------
# 총 결제 금액: 9,000원
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 127
#     124 print('='*44)
#     126 # 포인트 적립 여부 y/n 유효성 검사
# --> 127 ab = input('포인트를 적립하시겠습니까? (y/n): ')
#     129 while ab.lower() not in ['y', 'n']:
#     130     print('=' * 44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요: ')
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^44}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
            print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^44}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
#   Cell In[46], line 33
#     ord_num = int(input('주문하실 제품 번호를 선택하세요: ')
#                  ^
# SyntaxError: '(' was never closed

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: '))

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^44}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^44}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^44}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^44}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^44}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^44}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^44}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^44}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  2
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 화이트	2개	-	6000원
# --------------------------------------------
# 총 결제 금액: 6,000원
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 127
#     124 print('='*44)
#     126 # 포인트 적립 여부 y/n 유효성 검사
# --> 127 ab = input('포인트를 적립하시겠습니까? (y/n): ')
#     129 while ab.lower() not in ['y', 'n']:
#     130     print('=' * 44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: '))

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^44}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  r
# ============================================
#           [알림]다시 입력해주세요.
# ============================================
# 	수량을 입력하세요:  3
# 더 주문하시겠습니까? (y/n):  g
# ============================================
#               [알림] 잘못된 입력입니다.
#         [알림] 'y' 또는 'n'으로만 입력해 주세요.
# ============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 100
#      98     print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^44}')
#      99     print('='*44)
# --> 100     a = input('더 주문하시겠습니까? (y/n): ')
#     102 if a.lower() == 'n':
#     103     break
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]}원')
    print('-'*44)




    while True:
        # 다중 주문 저장 리스트
        order_list = []
        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print(f'{"[알림] 주문 취소를 원하시면 x를 입력하세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        elif a == 'x':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit():
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  v
# ============================================
#           [알림]다시 입력해주세요.
# ============================================
# 	수량을 입력하세요:  2
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	2개	-	2000원
# --------------------------------------------
# 총 결제 금액: 2,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  2
# ============================================
#           [알림] 잘못된 입력입니다.
#     [알림] 'y' 또는 'n'으로만 입력해 주세요.
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  134
# ============================================
# user_134 고객님의 적립포인트는 100점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6000원
# 2		볼펜		3000원
# 3		지우개		1000원
# 4		화이트		3000원
# 5		공책		3500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 33
#      31 order_list = []
#      32 try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 33     ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      35     if not (0 <= ord_num < len(menu)):
#      36         print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit() and len(phone) < 11:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  4
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	4개	-	4,000원
# --------------------------------------------
# 총 결제 금액: 4,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  4
# ============================================
#           고객님이 선택하신 제품은
#             화이트 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  6
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  1
# ============================================
#           고객님이 선택하신 제품은
#              샤프 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  2
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 화이트	6개	-	18,000원
# 샤프	2개	-	12,000원
# --------------------------------------------
# 총 결제 금액: 30,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 135
#     133 # 'y'일 경우 포인트 적립
#     134 if ab.lower() == 'y':
# --> 135     phone = input('전화번호를 입력해 주세요: ')
#     137     # 전화번호가 숫자가 아닐 경우 재입력 요구
#     138     while not phone.isdigit() and len(phone) < 11:
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 문구점 주문 시스템 (콘솔용)

import time

menu = [
    {'name': '샤프', 'price': 6000},
    {'name': '볼펜', 'price': 3000},
    {'name': '지우개', 'price': 1000},
    {'name': '화이트', 'price': 3000},
    {'name': '공책', 'price': 3500}
]

while True:
    order_list = []  # 주문 누적 리스트

    space = ' ' * 7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')

    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-' * 44)

    for i, m in enumerate(menu):
        print(f'{i + 1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-' * 44)

    while True:
        ord_input = input('주문하실 제품 번호를 선택하세요 (x:취소): ')
        if ord_input.lower() == 'x':
            order_list = []  # 주문 초기화
            break  # 시작화면으로 돌아감
        if not ord_input.isdigit():
            print("[알림] 숫자로 입력해 주세요.")
            continue

        ord_num = int(ord_input) - 1
        if not (0 <= ord_num < len(menu)):
            print("[알림] 메뉴에 없는 제품 번호입니다.")
            continue

        menut = menu[ord_num]['name']
        print(f'고객님이 선택하신 제품은 {menut} 입니다.')

        while True:
            qty_input = input('수량을 입력하세요 (x:취소): ')
            if qty_input.lower() == 'x':
                order_list = []  # 주문 초기화
                break  # 시작화면으로 돌아감
            if not qty_input.isdigit() or int(qty_input) <= 0:
                print("[알림] 수량은 1 이상 숫자로 입력해주세요.")
                continue
            qty = int(qty_input)
            break
        else:
            continue

        # 중복 제품 수량 증가
        for item in order_list:
            if item['name'] == menut:
                item['qty'] += qty
                break
        else:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        more = input('더 주문하시겠습니까? (y/n): ')
        if more.lower() == 'n':
            break

    if not order_list:
        print("[알림] 주문이 없습니다. 초기 화면으로 돌아갑니다.")
        continue

    total = 0
    print('=' * 44)
    print('\t\t주문 내역')
    print('-' * 44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total
        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-' * 44)
    print(f'총 결제 금액: {total:,}원')
    print('=' * 44)

    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    while ab.lower() not in ['y', 'n']:
        ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")

    if ab.lower() == 'y':
        phone = input('전화번호를 입력해주세요: ')
        while not phone.isdigit() or len(phone) < 4:
            phone = input("[알림] 전화번호는 숫자만 입력해주세요: ")

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('=' * 44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"감사합니다. 다음에 또 오세요!":^37}')
    print('=' * 44)
    time.sleep(3)  # 3초 대기 후 시작화면
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요 (x:취소):  4
# 고객님이 선택하신 제품은 화이트 입니다.
# 수량을 입력하세요 (x:취소):  x
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 화이트	2개	-	6,000원
# --------------------------------------------
# 총 결제 금액: 6,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
# ============================================
#             결제가 완료되었습니다.
#           감사합니다. 다음에 또 오세요!
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 30
#      27 print('-' * 44)
#      29 while True:
# ---> 30     ord_input = input('주문하실 제품 번호를 선택하세요 (x:취소): ')
#      31     if ord_input.lower() == 'x':
#      32         order_list = []  # 주문 초기화
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 문구점 주문 시스템 (콘솔용)

import time

menu = [
    {'name': '샤프', 'price': 6000},
    {'name': '볼펜', 'price': 3000},
    {'name': '지우개', 'price': 1000},
    {'name': '화이트', 'price': 3000},
    {'name': '공책', 'price': 3500}
]

while True:
    order_list = []  # 주문 누적 리스트

    space = ' ' * 7
    print('╔' + '═' * 40 + '╗')
    print(f'	{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')

    print(f'{"번호"}		{"제품명"}		{"가격"}')
    print('-' * 44)

    for i, m in enumerate(menu):
        print(f'{i + 1}		{m["name"]}		{m["price"]:,}원')
    print('-' * 44)

    while True:
        ord_input = input('주문하실 제품 번호를 선택하세요 (x:취소): ')
        if ord_input.lower() == 'x':
            order_list = []  # 주문 초기화
            break  # 시작화면으로 돌아감
        if not ord_input.isdigit():
            print("[알림] 숫자로 입력해 주세요.")
            continue

        ord_num = int(ord_input) - 1
        if not (0 <= ord_num < len(menu)):
            print("[알림] 메뉴에 없는 제품 번호입니다.")
            continue

        menut = menu[ord_num]['name']
        print(f'고객님이 선택하신 제품은 {menut} 입니다.')

        while True:
            qty_input = input('수량을 입력하세요 (x:취소): ')
            if qty_input.lower() == 'x':
                order_list = []  # 주문 초기화
                break  # 시작화면으로 돌아감
            if not qty_input.isdigit() or int(qty_input) <= 0:
                print("[알림] 수량은 1 이상 숫자로 입력해주세요.")
                continue
            qty = int(qty_input)
            break
        else:
            continue

        # 중복 제품 수량 증가
        for item in order_list:
            if item['name'] == menut:
                item['qty'] += qty
                break
        else:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        more = input('더 주문하시겠습니까? (y/n): ')
        if more.lower() == 'n':
            break

    if not order_list:
        print("[알림] 주문이 없습니다. 초기 화면으로 돌아갑니다.")
        continue

    total = 0
    print('=' * 44)
    print('\t\t주문 내역')
    print('-' * 44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total
        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-' * 44)
    print(f'총 결제 금액: {total:,}원')
    print('=' * 44)

    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    while ab.lower() not in ['y', 'n']:
        ab = input("[알림] 'y' 또는 'n'으로 입력해주세요: ")

    if ab.lower() == 'y':
        phone = input('전화번호를 입력해주세요: ')
        while not phone.isdigit() or len(phone) < 4:
            phone = input("[알림] 전화번호는 숫자만 입력해주세요: ")

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)
        print(f'{user_id} 고객님의 적립포인트는 {point:,}점 입니다.')

    print('=' * 44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"감사합니다. 다음에 또 오세요!":^37}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('=' * 44)
    time.sleep(3)  # 3초 대기 후 시작화면
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요 (x:취소):  3
# 고객님이 선택하신 제품은 지우개 입니다.
# 수량을 입력하세요 (x:취소):  2
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	2개	-	2,000원
# --------------------------------------------
# 총 결제 금액: 2,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해주세요:  2
# [알림] 전화번호는 숫자만 입력해주세요:  0101123456789
# user_6789 고객님의 적립포인트는 100점 입니다.
# ============================================
#             결제가 완료되었습니다.
#           감사합니다. 다음에 또 오세요!
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 30
#      27 print('-' * 44)
#      29 while True:
# ---> 30     ord_input = input('주문하실 제품 번호를 선택하세요 (x:취소): ')
#      31     if ord_input.lower() == 'x':
#      32         order_list = []  # 주문 초기화
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time

# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit() and len(phone) < 11:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        if user_id in points :
            points[user_id] += point
        else :
            points[user_id] = point

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
    time.sleep(3)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  4
# 더 주문하시겠습니까? (y/n):  ㅜ
# ============================================
#           [알림] 잘못된 입력입니다.
#     [알림] 'y' 또는 'n'으로만 입력해 주세요.
# ============================================
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	4개	-	4,000원
# --------------------------------------------
# 총 결제 금액: 4,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# user_5678 고객님의 적립포인트는 200점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 37
#      34 while True:
#      36     try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 37         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      39         if not (0 <= ord_num < len(menu)):
#      40             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit() and len(phone) < 11:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        if user_id in points :
            points[user_id] += point
        else :
            points[user_id] = point

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print('='*44)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 63
#      60 while True: ### 수량값 음수 및 문자 입력 방지 ###
#      61     try:
# ---> 63         qty = int(input('\t수량을 입력하세요: '))
#      64         if qty <=0:
#      65             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time

# 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
    
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = int(input('\t수량을 입력하세요: '))
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

            
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    # 총액 계산 및 주문 출력
    total = 0

    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)

    # 포인트 적립 여부 y/n 유효성 검사
    ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
    while ab.lower() not in ['y', 'n']:
        print('=' * 44)
        print(f'{"[알림] 잘못된 입력입니다.":^35}')
        print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
        print('=' * 44)
        ab = input('포인트를 적립하시겠습니까? (y/n): ')

    # 'y'일 경우 포인트 적립
    if ab.lower() == 'y':
        phone = input('전화번호를 입력해 주세요: ')
        
        # 전화번호가 숫자가 아닐 경우 재입력 요구
        while not phone.isdigit() and len(phone) < 11:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
            print('=' * 44)
            phone = input('전화번호를 다시 입력해 주세요: ')

        user_id = f'user_{phone[-4:]}'
        point = int(total * 0.05)

        if user_id in points :
            points[user_id] += point
        else :
            points[user_id] = point

        print('=' * 44)
        print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')

    print('='*44)
    print(f'{"결제가 완료되었습니다.":^37}')
    print(f'{"잠시만 기다려주세요.":^37}')
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
    time.sleep(3)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요:  4
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	4개	-	4,000원
# --------------------------------------------
# 총 결제 금액: 4,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
#                  감사합니다.
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 37
#      34 while True:
#      36     try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 37         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      39         if not (0 <= ord_num < len(menu)):
#      40             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time

# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        go_to_start = False
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요(취소: x): ')

                if qty == 'x':
                    go_to_start = True
                    break
                else:
                    qty = int(qty)
                
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

        if go_to_start:
            break
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    if not go_to_start:
        # 총액 계산 및 주문 출력
        total = 0
    
        print('='*44)
        print(f'\t\t{"주문 내역"}')
        print('-'*44)
    
        for order in order_list:
            item_total = order['qty'] * order['price']
            total += item_total
    
            print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')
    
        print('-'*44)
        print(f'총 결제 금액: {total:,}원')
        print('='*44)
    
        # 포인트 적립 여부 y/n 유효성 검사
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        
        while ab.lower() not in ['y', 'n']:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('=' * 44)
            ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
        # 'y'일 경우 포인트 적립
        if ab.lower() == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            
            # 전화번호가 숫자가 아닐 경우 재입력 요구
            while not phone.isdigit() or len(phone) < 11 or phone == "x":
                print('=' * 44)
                print(f'{"[알림] 잘못된 입력입니다.":^35}')
                print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
                print('=' * 44)
                phone = input('전화번호를 다시 입력해 주세요: ')
                
        if ab.lower() == 'y':
            user_id = f'user_{phone[-4:]}'
            point = int(total * 0.05)
        
            if user_id in points :
                points[user_id] += point
            else :
                points[user_id] = point
    
            print('=' * 44)
            print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')


        print('='*44)
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

    print('='*44)
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
    print('='*44)
		time.sleep(3)
# Out:
#   File <string>:181
#     time.sleep(3)
#                  ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
import time

# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        go_to_start = False
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요(취소: x): ')

                if qty == 'x':
                    go_to_start = True
                    break
                else:
                    qty = int(qty)
                
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

        if go_to_start:
            break
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    if not go_to_start:
        # 총액 계산 및 주문 출력
        total = 0
    
        print('='*44)
        print(f'\t\t{"주문 내역"}')
        print('-'*44)
    
        for order in order_list:
            item_total = order['qty'] * order['price']
            total += item_total
    
            print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')
    
        print('-'*44)
        print(f'총 결제 금액: {total:,}원')
        print('='*44)
    
        # 포인트 적립 여부 y/n 유효성 검사
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        
        while ab.lower() not in ['y', 'n']:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('=' * 44)
            ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
        # 'y'일 경우 포인트 적립
        if ab.lower() == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            
            # 전화번호가 숫자가 아닐 경우 재입력 요구
            while not phone.isdigit() or len(phone) < 11 or phone == "x":
                print('=' * 44)
                print(f'{"[알림] 잘못된 입력입니다.":^35}')
                print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
                print('=' * 44)
                phone = input('전화번호를 다시 입력해 주세요: ')
                
        if ab.lower() == 'y':
            user_id = f'user_{phone[-4:]}'
            point = int(total * 0.05)
        
            if user_id in points :
                points[user_id] += point
            else :
                points[user_id] = point
    
            print('=' * 44)
            print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')


        print('='*44)
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

    print('='*44)
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
	time.sleep(3)
# Out:
#   File <string>:180
#     time.sleep(3)
#                  ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
import time


# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        go_to_start = False
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요(취소: x): ')

                if qty == 'x':
                    go_to_start = True
                    break
                else:
                    qty = int(qty)
                
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

        if go_to_start:
            break
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    if not go_to_start:
        # 총액 계산 및 주문 출력
        total = 0
    
        print('='*44)
        print(f'\t\t{"주문 내역"}')
        print('-'*44)
    
        for order in order_list:
            item_total = order['qty'] * order['price']
            total += item_total
    
            print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')
    
        print('-'*44)
        print(f'총 결제 금액: {total:,}원')
        print('='*44)
    
        # 포인트 적립 여부 y/n 유효성 검사
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        
        while ab.lower() not in ['y', 'n']:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('=' * 44)
            ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
        # 'y'일 경우 포인트 적립
        if ab.lower() == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            
            # 전화번호가 숫자가 아닐 경우 재입력 요구
            while not phone.isdigit() or len(phone) < 11 or phone == "x":
                print('=' * 44)
                print(f'{"[알림] 잘못된 입력입니다.":^35}')
                print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
                print('=' * 44)
                phone = input('전화번호를 다시 입력해 주세요: ')
                
        if ab.lower() == 'y':
            user_id = f'user_{phone[-4:]}'
            point = int(total * 0.05)
        
            if user_id in points :
                points[user_id] += point
            else :
                points[user_id] = point
    
            print('=' * 44)
            print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')


        print('='*44)
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

    print('='*44)
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
    print('='*44)
    time.sleep(3)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  x
# ============================================
#                  감사합니다.
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 38
#      35 while True:
#      37     try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 38         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      40         if not (0 <= ord_num < len(menu)):
#      41             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time


# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        go_to_start = False
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요(취소: x): ')

                if qty == 'x':
                    go_to_start = True
                    break
                else:
                    qty = int(qty)
                
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

        if go_to_start:
            break
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    if not go_to_start:
        # 총액 계산 및 주문 출력
        total = 0
    
        print('='*44)
        print(f'\t\t{"주문 내역"}')
        print('-'*44)
    
        for order in order_list:
            item_total = order['qty'] * order['price']
            total += item_total
    
            print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')
    
        print('-'*44)
        print(f'총 결제 금액: {total:,}원')
        print('='*44)
    
        # 포인트 적립 여부 y/n 유효성 검사
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        
        while ab.lower() not in ['y', 'n']:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('=' * 44)
            ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
        # 'y'일 경우 포인트 적립
        if ab.lower() == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            
            # 전화번호가 숫자가 아닐 경우 재입력 요구
            while not phone.isdigit() or len(phone) < 11 or phone == "x":
                print('=' * 44)
                print(f'{"[알림] 잘못된 입력입니다.":^35}')
                print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
                print('=' * 44)
                phone = input('전화번호를 다시 입력해 주세요: ')
                
        if ab.lower() == 'y':
            user_id = f'user_{phone[-4:]}'
            point = int(total * 0.05)
        
            if user_id in points :
                points[user_id] += point
            else :
                points[user_id] = point
    
            print('=' * 44)
            print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')


        print('='*44)
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

    print('='*44)
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    print('='*44)
    time.sleep(3)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  2
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  5
# ============================================
#           고객님이 선택하신 제품은
#              공책 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	2개	-	2,000원
# 공책	3개	-	10,500원
# --------------------------------------------
# 총 결제 금액: 12,500원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# user_5678 고객님의 적립포인트는 625점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
# ============================================
#                  감사합니다.
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 38
#      35 while True:
#      37     try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
# ---> 38         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      40         if not (0 <= ord_num < len(menu)):
#      41             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time


# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

points = {}

while True:

    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝')


    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

    # 다중 주문 저장 리스트
    order_list = []


    while True:

        try: ### 제품번호 범위 및 숫자 외 입력 방지 ###
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1

            if not (0 <= ord_num < len(menu)): 
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue 


        except ValueError:  
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 제품 번호를 숫자로 입력해 주세요.":^35}')
            print('='*44)
            continue 
        
        menut = menu[ord_num]['name']

        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        go_to_start = False
        
        while True: ### 수량값 음수 및 문자 입력 방지 ###
            try:

                qty = input('\t수량을 입력하세요(취소: x): ')

                if qty == 'x':
                    go_to_start = True
                    break
                else:
                    qty = int(qty)
                
                if qty <=0:
                    print('='*44)
                    print(f'{"[알림]수량은 1개 이상 입력해주세요.":^35}')
                    print('='*44)
                    continue
                break

            except ValueError:
                print('='*44)
                print(f'{"[알림]다시 입력해주세요.":^35}')
                print('='*44)

        if go_to_start:
            break
                
        # 만약 같은 걸 더 주문하면 order_list 에 추가 말고 qty 만 +++
        flag = True
        for i in range(len(order_list)):
            if order_list[i]['name'] == menu[ord_num]["name"]:
                order_list[i]['qty'] += qty
                flag = False
                break

        # 새로운 거 주문 하면 append
        if flag:
            order_list.append({
                'name': menut,
                'qty': qty,
                'price': menu[ord_num]['price']
            })

        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            print('='*44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('='*44)
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break

        print('-'*44)

    if not go_to_start:
        # 총액 계산 및 주문 출력
        total = 0
    
        print('='*44)
        print(f'\t\t{"주문 내역"}')
        print('-'*44)
    
        for order in order_list:
            item_total = order['qty'] * order['price']
            total += item_total
    
            print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')
    
        print('-'*44)
        print(f'총 결제 금액: {total:,}원')
        print('='*44)
    
        # 포인트 적립 여부 y/n 유효성 검사
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        
        while ab.lower() not in ['y', 'n']:
            print('=' * 44)
            print(f'{"[알림] 잘못된 입력입니다.":^35}')
            print(f'{"[알림] 'y' 또는 'n'으로만 입력해 주세요.":^35}')
            print('=' * 44)
            ab = input('포인트를 적립하시겠습니까? (y/n): ')
    
        # 'y'일 경우 포인트 적립
        if ab.lower() == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            
            # 전화번호가 숫자가 아닐 경우 재입력 요구
            while not phone.isdigit() or len(phone) < 11 or phone == "x":
                print('=' * 44)
                print(f'{"[알림] 잘못된 입력입니다.":^35}')
                print(f'{"[알림] 전화번호는 숫자만 입력해 주세요.":^35}')
                print('=' * 44)
                phone = input('전화번호를 다시 입력해 주세요: ')
                
        if ab.lower() == 'y':
            user_id = f'user_{phone[-4:]}'
            point = int(total * 0.05)
        
            if user_id in points :
                points[user_id] += point
            else :
                points[user_id] = point
    
            print('=' * 44)
            print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')


        print('='*44)
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

    print('='*44)
    print(f'{"감사합니다.":^40}')
    print(f'{"3초 뒤에 시작화면으로 돌아갑니다.":^37}')
    time.sleep(1)
    print('='*44)
    print(f'{"2초 뒤에 시작화면으로 돌아갑니다.":^37}')
    time.sleep(1)
    print('='*44)
    print(f'{"1초 뒤에 시작화면으로 돌아갑니다.":^37}')
    time.sleep(1)
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  4
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	4개	-	4,000원
# --------------------------------------------
# 총 결제 금액: 4,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# user_5678 고객님의 적립포인트는 200점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
# ============================================
#                  감사합니다.
#          3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#          2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#          1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3

# %%
import time
points = {}

def prt_menu():
    space = ' '*7
    print('╔' + '═' * 40 + '╗')
    print(f'\t{space}빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

def prt_alarm():
    print('='*44)
    print(f'{"[알림] 잘못된 입력입니다.":^35}')
    print(f'{"[알림] 다시 입력해주세요.":^35}')
    print('='*44)

def prt_time():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(34))
        time.sleep(1)
        
def add_ord():
    while True:        
        try:
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
            if not (0 <= ord_num < len(menu)):
                print('='*44)
                print(f'{"[알림] 메뉴에 없는 제품 번호입니다.":^35}')
                print(f'{"[알림] 목록에 있는 제품 번호만 입력해 주세요.":^35}')
                print('='*44)
                continue
            return ord_num
        except ValueError:
            prt_alarm()
            continue
        
def add_qty():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() =="x":
            return qty
        try:
            qty = int(qty)
            if qty >0:
                return qty
            prt_alarm()
        except ValueError:
            prt_alarm()

def add_lst(order_list, ord_num, qty):
    item = menu[ord_num]
    for i in order_list:
        if i['name'] == item['name']:
            i['qty'] += qty
            return order_list 
    order_list.append({
        'name': item['name'],
        'qty': qty,
        'price': item['price']
    })
    return order_list
        
def calc_cost():
    total = 0   
    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)
    return total

def prt_points():
    while True:
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        if ab.lower() not in ['y', 'n']:
            prt_alarm()
            continue           
        elif ab.lower()=='n':
            return        
        else:
            while True:
                phone = input('전화번호를 입력해 주세요: ')
                if not phone.isdigit() or len(phone) < 11 or phone == "x":
                    prt_alarm()
                    continue                       
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)                 
                if user_id in points :
                    points[user_id] += point
                else :
                    points[user_id] = point
                print('='*44)
                print(f'{user_id} 고객님의 적립포인트는 {points[user_id]:,}점 입니다.')
                print('='*44)
                return
        
# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]
       
######################################################################################################################################################

while True:
    prt_menu()
    # 다중 주문 저장 리스트
    order_list = []

    while True: 
        ################## ord함수 추가####################
        ord_num = add_ord()         
        menut = menu[ord_num]['name']
        ##################################################
        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        ################## qty함수 추가####################
        qty = add_qty()
        if qty in ('x','X'):
            break
        ################## lst함수 추가####################        
        add_lst(order_list, ord_num, qty)
        ##################################################
        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            prt_alarm()
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        print('-'*44)

    if qty not in ('x','X'):
        ################# cost 함수 추가###################
        total = calc_cost()
        ################ points 함수 추가##################
        prt_points()
        ##################################################
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

        prt_time()
# Out:
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  2
# ============================================
#           고객님이 선택하신 제품은
#              볼펜 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 볼펜	3개	-	9,000원
# --------------------------------------------
# 총 결제 금액: 9,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  1234
# ============================================
#           [알림] 잘못된 입력입니다.
#           [알림] 다시 입력해주세요.
# ============================================
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# user_5678 고객님의 적립포인트는 450점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
# ============================================
#        3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  5
# ============================================
#           고객님이 선택하신 제품은
#              공책 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  800000
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  1
# ============================================
#           고객님이 선택하신 제품은
#              샤프 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3456789
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 공책	800000개	-	2,800,000,000원
# 샤프	3456789개	-	20,740,734,000원
# --------------------------------------------
# 총 결제 금액: 23,540,734,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
# ============================================
#        3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  1
# ============================================
#           고객님이 선택하신 제품은
#              샤프 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  2345678
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3456789
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 샤프	2345678개	-	14,074,068,000원
# 지우개	3456789개	-	3,456,789,000원
# --------------------------------------------
# 총 결제 금액: 17,530,857,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# user_5678 고객님의 적립포인트는 876,543,300점 입니다.
# ============================================
#             결제가 완료되었습니다.
#              잠시만 기다려주세요.
# ============================================
#        3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
# 	       빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 130
#     126 order_list = []
#     128 while True:
#     129     ################## ord함수 추가####################
# --> 130     ord_num = add_ord()
#     131     menut = menu[ord_num]['name']
#     132     ##################################################
#
# Cell In[1], line 32, in add_ord()
#      30 while True:
#      31     try:
# ---> 32         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      33         if not (0 <= ord_num < len(menu)):
#      34             print('='*44)
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time
points = {}
# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

def prt_menu(menu):
    print('╔' + '═' * 40 + '╗')
    print(f'\t   빵꾸똥꾸 문구야')
    print(f'{"에 오신 것을 환영합니다!":>25}')
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

def prt_alarm():
    print('='*44)
    print(f'{"[알림] 잘못된 입력입니다.":^35}')
    print(f'{"[알림] 다시 입력해주세요.":^35}')
    print('='*44)

def prt_time():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(34))
        time.sleep(1)
        
def add_ord():
    while True:        
        try:
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
            if not (0 <= ord_num < len(menu)):
                prt_alarm()
                continue
            return ord_num
        except ValueError:
            prt_alarm()
            continue
        
def add_qty():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() =="x":
            return qty
        try:
            qty = int(qty)
            if qty > 0:
                return qty
            prt_alarm()
        except ValueError:
            prt_alarm()

def add_lst(order_list, ord_num, qty):
    item = menu[ord_num]
    for i in order_list:
        if i['name'] == item['name']:
            i['qty'] += qty
            return order_list 
    order_list.append({
        'name': item['name'],
        'qty': qty,
        'price': item['price']
    })
    return order_list

def calc_cost():
    total = 0   
    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)
    return total

def prt_points():
    while True:
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        if ab.lower() not in ['y', 'n']:
            prt_alarm()
            continue
        elif ab.lower()=='n':
            return        
        else:
            while True:
                phone = input('전화번호를 입력해 주세요: ')
                if not phone.isdigit() or len(phone) < 11 or phone == "x":
                    prt_alarm()
                    continue                       
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)                 
                if user_id in points :
                    points[user_id] += point
                else :
                    points[user_id] = point
                print('='*44)
                print(f'🎁{user_id}고객님, {point}점 적립 되었습니다!🎁')
                print(f' 고객님의 총 적립포인트는 {points[user_id]:,}점 입니다!')
                print('='*44)
                return
     
######################################################################################################################################################


while True:
    prt_menu(menu)
    # 다중 주문 저장 리스트
    order_list = []

    while True: 
        
        ord_num = add_ord()         
        menut = menu[ord_num]['name']
        
        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        
        qty = add_qty()
        if qty in ('x','X'):
            break
             
        add_lst(order_list, ord_num, qty)
        
        a = input('더 주문하시겠습니까? (y/n): ')
            # y/n 입력 유효성 검사
        while a.lower() not in ['y', 'n']: ### y,n 외 입력 방지 ###
            prt_alarm()
            a = input('더 주문하시겠습니까? (y/n): ')
            
        if a.lower() == 'n':
            break
        print('-'*44)

    if qty not in ('x','X'):
        
        total = calc_cost()
        
        prt_points()
        
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요.":^37}')

        prt_time()
# Out:
# ╔════════════════════════════════════════╗
# 	   빵꾸똥꾸 문구야
#            에 오신 것을 환영합니다!
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 127
#     123 order_list = []
#     125 while True:
# --> 127     ord_num = add_ord()
#     128     menut = menu[ord_num]['name']
#     130     print('='*44)
#
# Cell In[11], line 39, in add_ord()
#      37 while True:
#      38     try:
# ---> 39         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      40         if not (0 <= ord_num < len(menu)):
#      41             prt_alarm()
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
class 연필:
    def __init__(self, 색깔, 길이):
        self.색깔 = 색깔
        self.길이 = 길이

    def 쓰기(self):
        return f"{self.색깔} 연필로 글을 씁니다."

# 연필 만들기
나의연필 = 연필("파랑", 17)

# 사용해보기
print(나의연필.쓰기())       # 파랑 연필로 글을 씁니다.
print(나의연필.길이)         # 17

연필 = "노란색 연필"
print(연필)
# Out:
# 파랑 연필로 글을 씁니다.
# 17
# 노란색 연필

# %%
def 연필_모양():
    print("      /\\")
    print("     /  \\")
    print("    /    \\")
    print("   /      \\")
    print("  /--------\\")
    print(" |          |")
    print(" |   연필   |")
    print(" |          |")
    print(" |__________|")

# %%
def draw_pencil_ascii():
    pencil_art = r'''
          .".
         /   \
         |  ||
         |  ||
         |  ||
         |  ||
         |  |/
         |__|
         |==|
         |  |
         |  |
         |  |
         |  |
         |  |
         \__/
          |/
          `
    '''
    print(pencil_art)

draw_pencil_ascii()
# Out:
#           .".
#          /   \
#          |  ||
#          |  ||
#          |  ||
#          |  ||
#          |  |/
#          |__|
#          |==|
#          |  |
#          |  |
#          |  |
#          |  |
#          |  |
#          \__/
#           |/
#           `

# %%
import time
points = {}
# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

def prt_menu(menu):
    print('╔' + '═' * 40 + '╗')
    print(f'빵꾸똥꾸 문구야'.center(34))
    print(f"에 오신 것을 환영합니다!💥".center(34))
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

def prt_alarm():
    print('='*44)
    print(f'{"[알림]❌ 잘못된 입력입니다.":^35}')
    print(f'{"[알림]✅ 다시 입력해주세요.":^35}')
    print('='*44)

def prt_time():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(34))
        time.sleep(1)
        
def add_ord():
    while True:        
        try:
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
            if not (0 <= ord_num < len(menu)):
                prt_alarm()
                continue
            return ord_num
        except ValueError:
            prt_alarm()
            continue
        
def add_qty():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() =="x":
            return qty
        try:
            qty = int(qty)
            if qty > 0:
                return qty
            prt_alarm()
        except ValueError:
            prt_alarm()

def add_lst(order_list, ord_num, qty):
    item = menu[ord_num]
    for i in order_list:
        if i['name'] == item['name']:
            i['qty'] += qty
            return order_list 
    order_list.append({
        'name': item['name'],
        'qty': qty,
        'price': item['price']
    })
    return order_list
    
def yesno():
    while True:
        a=input('더 주문하시겠습니까?(y/n):')
        if a.lower() not in ['y','n']:
            prt_alarm()
            continue
        else:
            return a
            
def calc_cost():
    total = 0   
    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)
    return total

def prt_points():
    while True:
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        if ab.lower() not in ['y', 'n']:
            prt_alarm()
            continue
        elif ab.lower()=='n':
            return        
        else:
            while True:
                phone = input('전화번호를 입력해 주세요: ')
                if not phone.isdigit() or len(phone) < 11 or phone == "x":
                    prt_alarm()
                    continue                       
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)                 
                if user_id in points :
                    points[user_id] += point
                else :
                    points[user_id] = point
                print('='*44)
                print(f'🎁{user_id}고객님, {point}점 적립 되었습니다!🎁')
                print(f' 고객님의 총 적립포인트는 {points[user_id]:,}점 입니다!')
                print('='*44)
                return
     
######################################################################################################################################################

# 이건 while True 루프 시작 전에 함수 정의
def draw_pencil_ascii():
    pencil_art = r"""
        .================ooooooo
 ___   ,'    \___________________________________
/   /-/       /                     ////////////  ''--..._
\___\-\       \                     \\\\\\\\\\\\  __..--'
       `---------------------------''''''''''''''
"""
    print(pencil_art)

# === 반복문 시작 ===
while True:
    prt_menu(menu)
    order_list = []

    while True: 
        ord_num = add_ord()
        menut = menu[ord_num]['name']
        
        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        qty = add_qty()
        if qty in ('x','X'):
            break
             
        add_lst(order_list, ord_num, qty)
        
        answer = yesno()
        if answer == 'n':
            break
        print('-'*44)

    if qty not in ('x','X'):
        total = calc_cost()
        prt_points()
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요. 😊":^37}')
        
        draw_pencil_ascii()  # ✅ 정상 위치
        prt_time()
# Out:
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  4
# 더 주문하시겠습니까?(y/n): n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	4개	-	4,000원
# --------------------------------------------
# 총 결제 금액: 4,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
#             결제가 완료되었습니다.
#             잠시만 기다려주세요. 😊
#
#         .================ooooooo
#  ___   ,'    \___________________________________
# /   /-/       /                     ////////////  ''--..._
# \___\-\       \                     \\\\\\\\\\\\  __..--'
#        `---------------------------''''''''''''''
#
# ============================================
#        3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#        1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 145
#     142 order_list = []
#     144 while True:
# --> 145     ord_num = add_ord()
#     146     menut = menu[ord_num]['name']
#     148     print('='*44)
#
# Cell In[11], line 39, in add_ord()
#      37 while True:
#      38     try:
# ---> 39         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      40         if not (0 <= ord_num < len(menu)):
#      41             prt_alarm()
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def draw_pencil_ascii():
    pencil_art = r"""
        .=======================ooooooo
 ___   ,'    \_________________________________________
/   /-/       /                           ////////////  ''--..._
\___\-\       \                           \\\\\\\\\\\\  __..--'
       `---------------------------------''''''''''''''
"""
    print(pencil_art)

draw_pencil_ascii()
# Out:
#         .=======================ooooooo
#  ___   ,'    \_________________________________________
# /   /-/       /                           ////////////  ''--..._
# \___\-\       \                           \\\\\\\\\\\\  __..--'
#        `---------------------------------''''''''''''''

# %%
import time

# 전역 포인트 저장소
points = {}

# 제품 메뉴 리스트
menu = [
    {'name': '샤프', 'price': 6000},
    {'name': '볼펜', 'price': 3000},
    {'name': '지우개', 'price': 1000},
    {'name': '화이트', 'price': 3000},
    {'name': '공책', 'price': 3500}
]

# 출력 함수들
def print_menu():
    print('╔' + '═' * 40 + '╗')
    print(f'{"빵꾸똥꾸 문구야":^42}')
    print(f'{"에 오신 것을 환영합니다!💥":^42}')
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t{"제품명"}\t\t{"가격"}')
    print('-' * 44)
    for i, item in enumerate(menu):
        print(f'{i+1}\t{item["name"]}\t\t{item["price"]:,}원')
    print('-' * 44)

def print_alarm(msg="잘못된 입력입니다. 다시 입력해주세요."):
    print('=' * 44)
    print(f'{msg:^44}')
    print('=' * 44)

def print_countdown():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(44))
        time.sleep(1)

def print_order_summary(order_list):
    print('=' * 44)
    print(f'\t\t{"주문 내역"}')
    print('-' * 44)
    total = 0
    for item in order_list:
        subtotal = item['qty'] * item['price']
        print(f'{item["name"]}\t{item["qty"]}개\t-\t{subtotal:,}원')
        total += subtotal
    print('-' * 44)
    print(f'총 결제 금액: {total:,}원')
    print('=' * 44)
    return total

# 사용자 입력 처리
def select_product():
    while True:
        try:
            index = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
            if 0 <= index < len(menu):
                return index
            else:
                print_alarm()
        except ValueError:
            print_alarm()

def input_quantity():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() == 'x':
            return 'x'
        if qty.isdigit() and int(qty) > 0:
            return int(qty)
        print_alarm()

def confirm_continue():
    while True:
        answer = input('더 주문하시겠습니까? (y/n): ').lower()
        if answer in ['y', 'n']:
            return answer
        print_alarm()

def add_to_order(order_list, index, qty):
    item = menu[index]
    for existing in order_list:
        if existing['name'] == item['name']:
            existing['qty'] += qty
            return
    order_list.append({'name': item['name'], 'qty': qty, 'price': item['price']})

def handle_point_system(total):
    while True:
        use_point = input('포인트를 적립하시겠습니까? (y/n): ').lower()
        if use_point == 'n':
            return
        elif use_point == 'y':
            phone = input('전화번호를 입력해 주세요: ')
            if phone.isdigit() and len(phone) >= 11:
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)
                points[user_id] = points.get(user_id, 0) + point
                print('=' * 44)
                print(f'🎁 {user_id} 고객님, {point}점 적립 되었습니다!')
                print(f'총 적립 포인트: {points[user_id]:,}점')
                print('=' * 44)
                return
            else:
                print_alarm('전화번호 형식이 잘못되었습니다.')
        else:
            print_alarm()

# 메인 루프
def main():
    while True:
        print_menu()
        order_list = []

        while True:
            product_index = select_product()
            product_name = menu[product_index]['name']
            print('=' * 44)
            print(f'고객님이 선택하신 제품은 "{product_name}"입니다.')
            print(f'몇 개를 드릴까요?')

            qty = input_quantity()
            if qty == 'x':
                break

            add_to_order(order_list, product_index, qty)

            if confirm_continue() == 'n':
                break
            print('-' * 44)

        if order_list:
            total = print_order_summary(order_list)
            handle_point_system(total)
            print(f'{"결제가 완료되었습니다.":^44}')
            print(f'{"잠시만 기다려주세요. 😊":^44}')
            print_countdown()

# 프로그램 실행
if __name__ == '__main__':
    main()
# Out:
# ╔════════════════════════════════════════╗
#                  빵꾸똥꾸 문구야
#              에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호	제품명		가격
# --------------------------------------------
# 1	샤프		6,000원
# 2	볼펜		3,000원
# 3	지우개		1,000원
# 4	화이트		3,000원
# 5	공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  2
# ============================================
# 고객님이 선택하신 제품은 "볼펜"입니다.
# 몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  4
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 볼펜	4개	-	12,000원
# --------------------------------------------
# 총 결제 금액: 12,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  n
#                 결제가 완료되었습니다.
#                잠시만 기다려주세요. 😊
# ============================================
#             3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#             2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#             1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
#                  빵꾸똥꾸 문구야
#              에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호	제품명		가격
# --------------------------------------------
# 1	샤프		6,000원
# 2	볼펜		3,000원
# 3	지우개		1,000원
# 4	화이트		3,000원
# 5	공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
# 고객님이 선택하신 제품은 "지우개"입니다.
# 몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  5
# 더 주문하시겠습니까? (y/n):  y
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  2
# ============================================
# 고객님이 선택하신 제품은 "볼펜"입니다.
# 몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  5
# 더 주문하시겠습니까? (y/n):  n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	5개	-	5,000원
# 볼펜	5개	-	15,000원
# --------------------------------------------
# 총 결제 금액: 20,000원
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  0123
# ============================================
#              전화번호 형식이 잘못되었습니다.
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  01012345678
# ============================================
#            잘못된 입력입니다. 다시 입력해주세요.
# ============================================
# 포인트를 적립하시겠습니까? (y/n):  y
# 전화번호를 입력해 주세요:  01012345678
# ============================================
# 🎁 user_5678 고객님, 1000점 적립 되었습니다!
# 총 적립 포인트: 1,000점
# ============================================
#                 결제가 완료되었습니다.
#                잠시만 기다려주세요. 😊
# ============================================
#             3초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#             2초 뒤에 시작화면으로 돌아갑니다.
# ============================================
#             1초 뒤에 시작화면으로 돌아갑니다.
# ╔════════════════════════════════════════╗
#                  빵꾸똥꾸 문구야
#              에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호	제품명		가격
# --------------------------------------------
# 1	샤프		6,000원
# 2	볼펜		3,000원
# 3	지우개		1,000원
# 4	화이트		3,000원
# 5	공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 141
#     139 # 프로그램 실행
#     140 if __name__ == '__main__':
# --> 141     main()
#
# Cell In[12], line 116, in main()
#     113 order_list = []
#     115 while True:
# --> 116     product_index = select_product()
#     117     product_name = menu[product_index]['name']
#     118     print('=' * 44)
#
# Cell In[12], line 56, in select_product()
#      54 while True:
#      55     try:
# ---> 56         index = int(input('주문하실 제품 번호를 선택하세요: ')) - 1
#      57         if 0 <= index < len(menu):
#      58             return index
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import time
points = {}
# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

def prt_menu(menu):
    print('╔' + '═' * 40 + '╗')
    print(f'빵꾸똥꾸 문구야'.center(34))
    print(f"에 오신 것을 환영합니다!💥".center(34))
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

def prt_alarm():
    print('='*44)
    print(f'{"[알림]❌ 잘못된 입력입니다.":^35}')
    print(f'{"[알림]✅ 다시 입력해주세요.":^35}')
    print('='*44)

def prt_time():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(34))
        time.sleep(1)
        
def add_ord():
    while True:        
        try:
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
            if not (0 <= ord_num < len(menu)):
                prt_alarm()
                continue
            return ord_num
        except ValueError:
            prt_alarm()
            continue
        
def add_qty():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() =="x":
            return qty
        try:
            qty = int(qty)
            if qty > 0:
                return qty
            prt_alarm()
        except ValueError:
            prt_alarm()

def add_lst(order_list, ord_num, qty):
    item = menu[ord_num]
    for i in order_list:
        if i['name'] == item['name']:
            i['qty'] += qty
            return order_list 
    order_list.append({
        'name': item['name'],
        'qty': qty,
        'price': item['price']
    })
    return order_list
    
def yesno():
    while True:
        a=input('더 주문하시겠습니까?(y/n):')
        if a.lower() not in ['y','n']:
            prt_alarm()
            continue
        else:
            return a
            
def calc_cost():
    total = 0   
    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)
    return total

def prt_points():
    while True:
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        if ab.lower() not in ['y', 'n']:
            prt_alarm()
            continue
        elif ab.lower()=='n':
            return        
        else:
            while True:
                phone = input('전화번호를 입력해 주세요: ')
                if not phone.isdigit() or len(phone) < 11 or phone == "x":
                    prt_alarm()
                    continue                       
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)                 
                if user_id in points :
                    points[user_id] += point
                else :
                    points[user_id] = point
                print('='*44)
                print(f'🎁{user_id}고객님, {point}점 적립 되었습니다!🎁')
                print(f' 고객님의 총 적립포인트는 {points[user_id]:,}점 입니다!')
                print('='*44)
                return
     
######################################################################################################################################################


def draw_pencil_ascii():
    pencil_art = r"""
        .================ooooooo
 ___   ,'    \_________________________________
/   /-/       /                   ////////////  ''--..._
\___\-\       \                   \\\\\\\\\\\\  __..--'
       `--------------------------''''''''''''''
"""
    print(pencil_art)

draw_pencil_ascii()
while True:
    prt_menu(menu)
    # 다중 주문 저장 리스트
    order_list = []

    while True: 
        
        ord_num = add_ord()         
        menut = menu[ord_num]['name']
        
        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        
        qty = add_qty()
        if qty in ('x','X'):
            break
             
        add_lst(order_list, ord_num, qty)
        
        answer = yesno()
        if answer == 'n':
            break
        print('-'*44)

    if qty not in ('x','X'):
        
        total = calc_cost()
        
        prt_points()
        
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요. 😊":^37}')

        prt_time()
# Out:
#         .================ooooooo
#  ___   ,'    \_________________________________
# /   /-/       /                   ////////////  ''--..._
# \___\-\       \                   \\\\\\\\\\\\  __..--'
#        `--------------------------''''''''''''''
#
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  2
# ============================================
#           고객님이 선택하신 제품은
#              볼펜 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  x
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# 주문하실 제품 번호를 선택하세요:  3
# ============================================
#           고객님이 선택하신 제품은
#             지우개 입니다.
#            몇 개를 드릴까요?
# 	수량을 입력하세요(취소: x):  3
# 더 주문하시겠습니까?(y/n): n
# ============================================
# 		주문 내역
# --------------------------------------------
# 지우개	3개	-	3,000원
# --------------------------------------------
# 총 결제 금액: 3,000원
# ============================================

# %%
import time
membership_dict = {}
menu_list = [
    {'name': '바나나', 'price': 4000},
    {'name': '딸기', 'price': 5000},
    {'name': '벌집꿀', 'price': 7000},
    {'name': '그레놀라', 'price': 7000},
    {'name': '초코쉘', 'price': 7000},
    {'name': '요거트 아이스크림', 'price': 3000}
]

def get_valid_number_input(msg, min_no = 1, max_no = 5):
    # 숫자체크
    try:
        number = int(input(msg))
        if number < min_no:
            print(f"{min_no} 이상 숫자를 입력하세요")
            return None
        elif number > max_no:
            print(f"{max_no} 이하 숫자를 입력하세요")
            return None
        else:
            return number
    except ValueError:
        print("숫자를 입력하세요")
        return None

def display_menu():
    print('*' * 40)
    print('어서오세요, ‘요렇게’에 오신 것을 환영합니다:)')
    print("Menu\t\t\t\tPrice")
    print("-" * 30)
    print("요거트 아이스크림(250g)\t3,000")
    print("-" * 30)
    print("\nNo. Topping\t\tPrice")
    print("-" * 30)
    for idx, item in enumerate(menu_list, start=1):
        print(f"{idx:<5} {item['name']:<10}\t{item['price']:,}")
    print("-" * 30)
    print("*" * 40)

def display_cart(cart, total_price):
    print("\n" + "=" * 40)
    print("현재 장바구니")
    for i, item in enumerate(cart, start=1):
        print(f"{i}. {item['name']} x {item['quantity']} = {item['price'] * item['quantity']:,}원")
    print("-" * 40)
    print(f"Total = {total_price:,}원")

def add_menu(cart, total_price):
    current_total = sum(item['quantity'] for item in cart)
    remaining = 16 - current_total
    
    if remaining <= 0:
        print("장바구니에는 최대 15개까지만 담을 수 있습니다.")
        return total_price

    print("\n메뉴 목록:")
    for i, item in enumerate(menu_list, start=1):
        print(f"{i}. {item['name']} : {item['price']:,}원")
    idx = get_valid_number_input("추가할 토핑 번호를 골라주세요 : ", 1, len(menu_list))
    if idx:
        idx -= 1
        qty = get_valid_number_input(f"수량을 선택해주세요 (남은 수량: {remaining}) : ",1,remaining)
        if qty:
            selected_item = menu_list[idx]
            for item in cart:
                if item['name'] == selected_item['name']:
                    item['quantity'] += qty
                    if item['quantity'] > 15:
                        item['quantity'] = 15
                    break
            else:
                cart.append({'name': selected_item['name'], 'quantity': qty, 'price': selected_item['price']})
    
            total_price += selected_item['price'] * qty
    return total_price

def del_menu(cart, total_price):
    display_cart(cart, total_price)
    idx = get_valid_number_input("삭제할 메뉴의 번호를 골라주세요 : ",1,len(cart))
    if idx:
        idx -= 1
        item = cart[idx]
        print(f"'{item['name']}'의 현재 수량: {item['quantity']}")
        del_qty = get_valid_number_input("몇 개를 삭제하시겠습니까? : ", 1, item['quantity'])
        if del_qty:
            item['quantity'] -= del_qty
            total_price -= item['price'] * del_qty
            print(f"'{item['name']}' {del_qty}개가 삭제되었습니다.")
    return total_price

def select_pro():
    print("메뉴를 확정하려면 o")
    print("메뉴를 삭제하려면 d")
    print("메뉴를 추가하려면 a")
    print("메뉴를 취소하려면 c")
    return input("알파벳을 입력해주세요 : ").lower().strip()

def pay_deci():
    return input("주문이 확정되었습니다. 결제를 하시겠습니까? (y/n): ").lower().strip()

def pay_screen(total_price, num_order):
    print(f"{total_price:,}원 결제하겠습니다. 카드를 삽입해주세요.")
    print("결제가 완료되었습니다.")
    mem = input("적립 하시겠습니까? (y/n): ").lower().strip()
    if mem.lower() == 'y':
        membership_point_save(total_price)
    print(f"주문번호는 {num_order}번 입니다.")

def membership_point_save(total_price):
    phone = input("전화번호를 입력해주세요 (- 없이): ").strip()
    points = int(total_price * 0.1)

    if phone in membership_dict:
        membership_dict[phone] += points
        print(f"{phone} 번호에 {points}포인트가 추가되어, 총 {membership_dict[phone]}포인트가 있습니다.")
    else:
        membership_dict[phone] = points
        print(f"{phone} 번호로 {points}포인트가 새로 적립되었습니다.")

def end_screen_delay():
    print("초기화면으로 돌아갑니다.")
    for i in range(5, 0, -1):
        print(f"{i} ", end='\r', flush=True)
        time.sleep(1)
    print(" ", end='\r')

def main():
    num_order = 1
    while True:
        display_menu()
        cart = [{'name': menu_list[5]['name'], 'price': menu_list[5]['price'], 'quantity': 1}]
        total_price = 3000
        while True:
            display_cart(cart, total_price)
            choice = select_pro()

            if choice == 'o':
                break
            elif choice == 'd':
                total_price = del_menu(cart, total_price)
            elif choice == 'a':
                total_price = add_menu(cart, total_price)
            elif choice == 'c':
                print("주문이 취소됩니다.")
                end_screen_delay()
                break
            elif choice == '99':
                print("관리자 중지입니다.")
                return
            else:
                print("입력이 올바르지 않습니다.")

        if choice in ['c', '99']:
            continue
        if total_price == 0:
            print("장바구니가 비어있습니다.")
            end_screen_delay()
            continue

        if pay_deci() == 'y':
            pay_screen(total_price, num_order)
            num_order += 1
        end_screen_delay()

main()
# Out:
# ****************************************
# 어서오세요, ‘요렇게’에 오신 것을 환영합니다:)
# Menu				Price
# ------------------------------
# 요거트 아이스크림(250g)	3,000
# ------------------------------
#
# No. Topping		Price
# ------------------------------
# 1     바나나       	4,000
# 2     딸기        	5,000
# 3     벌집꿀       	7,000
# 4     그레놀라      	7,000
# 5     초코쉘       	7,000
# 6     요거트 아이스크림 	3,000
# ------------------------------
# ****************************************
#
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# ----------------------------------------
# Total = 3,000원
# 메뉴를 확정하려면 o
# 메뉴를 삭제하려면 d
# 메뉴를 추가하려면 a
# 메뉴를 취소하려면 c
# 알파벳을 입력해주세요 :  a
# 메뉴 목록:
# 1. 바나나 : 4,000원
# 2. 딸기 : 5,000원
# 3. 벌집꿀 : 7,000원
# 4. 그레놀라 : 7,000원
# 5. 초코쉘 : 7,000원
# 6. 요거트 아이스크림 : 3,000원
# 추가할 토핑 번호를 골라주세요 :  5
# 수량을 선택해주세요 (남은 수량: 15) :  10
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# 2. 초코쉘 x 10 = 70,000원
# ----------------------------------------
# Total = 73,000원
# 메뉴를 확정하려면 o
# 메뉴를 삭제하려면 d
# 메뉴를 추가하려면 a
# 메뉴를 취소하려면 c
# 알파벳을 입력해주세요 :  o
# 주문이 확정되었습니다. 결제를 하시겠습니까? (y/n):  y
# 73,000원 결제하겠습니다. 카드를 삽입해주세요.
# 결제가 완료되었습니다.
# 적립 하시겠습니까? (y/n):  n
# 주문번호는 1번 입니다.
# 초기화면으로 돌아갑니다.
# ****************************************
# 어서오세요, ‘요렇게’에 오신 것을 환영합니다:)
# Menu				Price
# ------------------------------
# 요거트 아이스크림(250g)	3,000
# ------------------------------
#
# No. Topping		Price
# ------------------------------
# 1     바나나       	4,000
# 2     딸기        	5,000
# 3     벌집꿀       	7,000
# 4     그레놀라      	7,000
# 5     초코쉘       	7,000
# 6     요거트 아이스크림 	3,000
# ------------------------------
# ****************************************
#
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# ----------------------------------------
# Total = 3,000원
# 메뉴를 확정하려면 o
# 메뉴를 삭제하려면 d
# 메뉴를 추가하려면 a
# 메뉴를 취소하려면 c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 167
#     164             num_order += 1
#     165         end_screen_delay()
# --> 167 main()
#
# Cell In[18], line 137, in main()
#     135 while True:
#     136     display_cart(cart, total_price)
# --> 137     choice = select_pro()
#     139     if choice == 'o':
#     140         break
#
# Cell In[18], line 98, in select_pro()
#      96 print("메뉴를 추가하려면 a")
#      97 print("메뉴를 취소하려면 c")
# ---> 98 return input("알파벳을 입력해주세요 : ").lower().strip()
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 유틸리티 함수

# yes or no
def get_yes_or_no_input(msg):
    while True:
        user_input = input('>>>' + msg + " (yes/no): ").strip().lower()
        if user_input in ['yes', 'no']:
            return user_input
        else:
            print("⚠️  'yes' 또는 'no'만 입력할 수 있어요.")


#숫자검증
def get_valid_number_input(msg, min_no=0, max_no=5):
    try:
        number = int(input('>>>' + msg).strip())
        if number < min_no:
            print(f'{min_no} 이상 숫자를 입력하세요.')
            return None
        elif number > max_no:
            print(f'{max_no} 이하 숫자를 입력하세요.')
            return None
        else:
            return number
    except ValueError:
        print('숫자로 입력하세요.')
        return None

# 데이터 초기화
cart = {'user_menu': '', 'user_size': '', 'qty': ''}
cart_list = []
membership_dict = {}

menu_list = ['초코', '바닐라', '딸기', '우유', '말차', '민트초코']
size_price = {'S': 2000, 'M': 3000, 'L': 4000}
size_list = list(size_price.keys())

# 멤버십 적립 함수
def handle_membership():
    while True:
        member = input("멤버십을 적립하시겠습니까? (yes/no): ").strip().lower() 
        if member not in ['yes', 'no']:
            print("yes 또는 no만 입력해주세요.")
            continue
        if member == 'no':
            print("멤버십 적립을 건너뜁니다.\n")
            return
        else:
            print("멤버십 적립을 선택하셨습니다.")
            while True:
                phone = input("전화 번호를 11자리를 입력하세요: ").strip()
                if len(phone) != 11 or not phone.isdigit():
                    print("전화번호가 올바르지 않습니다. 11자리 숫자만 입력해주세요.")
                    continue
                if phone in membership_dict:
                    print(f"기존 ({phone}) 번호의 멤버십이 있으므로 포인트를 적립했습니다.\n")
                else:
                    membership_dict[phone] = {}
                    print(f"새로운 ({phone}) 번호로 멤버십이 생성되었습니다.\n")
                return

# 장바구니 출력
def print_cart():
    if not cart_list:
        print("\n장바구니가 비어 있습니다.")
        return
    print("\n🛒 현재 장바구니:")
    for i, item in enumerate(cart_list, 1):
        print(f"{i}. {item['user_menu']} ({item['user_size']}) x {item['qty']}개 - {item['total_price']:,}원")
    total = sum(item['total_price'] for item in cart_list)
    print(f"총 합계: {total:,}원")

# 장바구니 보기 및 결제
def function5():
    if not cart_list:
        print("\n장바구니가 비어 있습니다.")
        start()
        return 
    print_cart()
    while True:
        ask_mul = '1. 결제하기  2. 계속 쇼핑하기  0: '
        choice = get_valid_number_input(ask_mul, 0, 2) ## 예외처리 (0~3)
        if choice == 1:
            total = sum(item['total_price'] for item in cart_list)
            print(f"\n총 결제 금액: {total:,}원")

            answer = get_yes_or_no_input("결제하시겠습니까? (yes/no): ") #예외처리 (yes or no)
            if answer not in ['yes', 'no']:
                print("yes 또는 no만 입력해주세요.")
                continue
            elif answer == 'no':
                print("주문이 취소되었습니다.\n")
                return start()

            # 멤버십 적립 처리
            handle_membership()

            print("결제가 완료되었습니다. 감사합니다! 🍦\n")
            cart_list.clear()
            start()
            return

        elif choice == 2:
            return function_1()
        elif choice == 0:
            print("\n이용해주셔서 감사합니다! 좋은 하루 되세요! 👋")
            exit()

# 장바구니 상품 삭제
def function4():
    if not cart_list:
        print("\n장바구니가 비어 있습니다.")
        return
    print_cart()
    try:
        idx = int(input("삭제할 상품 번호를 입력하세요 (취소하려면 0 입력): ")) #예외처리 못함 ㅜㅡㅜ
        if idx == 0:
            print("삭제를 취소했습니다.")
            return
        if 1 <= idx <= len(cart_list):
            removed = cart_list.pop(idx - 1)
            print(f"{removed['user_menu']} ({removed['user_size']}) x {removed['qty']}개가 장바구니에서 삭제되었습니다.")
        else:
            print("⛔ 유효한 번호를 입력하세요.")
    except ValueError:
        print("⛔ 숫자를 입력해주세요.")

# 장바구니에 추가 및 장바구니 기능 선택
def function_3():
    item = {
        'user_menu': cart['user_menu'],
        'user_size': cart['user_size'],
        'qty': cart['qty'],
        'price_per_item': size_price[cart['user_size']],
        'total_price': size_price[cart['user_size']] * cart['qty']
    }
    cart_list.append(item)

    print("\n🍦 장바구니에 추가되었습니다! 🍦")
    print_cart()

    while True:
        cho_mul = "\n1. 계속 쇼핑하기  2. 장바구니 보기 및 결제  3. 장바구니에서 상품 삭제  0. 종료\n선택: "
        choice = get_valid_number_input(cho_mul, 0, 3) ## 예외처리 (0~3)
        if choice == 1:
            function_1()
            return
        elif choice == 2:
            function5()
            return
        elif choice == 3:
            function4()
        elif choice == 0:
            print("\n이용해주셔서 감사합니다! 좋은 하루 되세요! 👋")
            exit()

# 수량 선택
def function_2():
    while True:
        print("\n🍨 사이즈 및 가격\n")
        for i, (size, price) in enumerate(size_price.items()):
            print(f'{i + 1}. 사이즈: {size}, 가격: {price:,}원')
        size_mul = f"\n원하시는 사이즈를 선택해주세요. (1~{len(size_price)}, 0:뒤로가기): "
        size_index = get_valid_number_input(size_mul, 0,3 )## 예외처리 (0~3)
        
        if size_index is None:
            print("⛔ 입력 오류⛔ 사이즈 다시 선택하세요.")

        elif size_index == 0:
            print('\n뒤로 돌아갑니다 ⬅️')
            function_1()
            return
        elif 1 <= size_index <= len(size_price):
            cart['user_size'] = size_list[size_index - 1]
            break
    while True:
        qty_mul = "🤟 원하시는 개수를 적어주세요 (0:뒤로가기): "
        qty = get_valid_number_input(qty_mul, 0, 10) ## 예외처리 (0~10) 성공
        if qty == None:
            continue
        if qty == 0:
            print('\n사이즈 선택으로 돌아갑니다 ⬅️')
            function_2()
            return
        if qty > 0:
            cart['qty'] = qty
            break
    print('-' * 50)
    function_3()
    

# 메뉴 선택
def function_1():
    while True:
        print("\n📋 메뉴판\n")
        for index, name in enumerate(menu_list):
            print(f'{index + 1}. {name}')
        
        menu_mul = f"\n원하시는 메뉴를 선택해주세요. (1~{len(menu_list)}, 0:처음으로): "
        menu_index = get_valid_number_input(menu_mul, 0, len(menu_list))  # 예외처리 

        if menu_index is None:
            continue  # None일 경우 아무 처리 없이 다시 메뉴 선택

        if menu_index == 0:
            print('\n보고싶을거예요 😭😭\n')
            start()
            return

        if 1 <= menu_index <= len(menu_list):
            cart['user_menu'] = menu_list[menu_index - 1]
            print('-' * 50)
            function_2()
            return
# 시작 화면
def start():
    print('=' * 50)
    store_name = 'I Miss You Cram!🍦'
    print(f'        보고싶었어요! {store_name}')
    print('=' * 50)
    function_1()

# main
start()
# Out:
# ==================================================
#         보고싶었어요! I Miss You Cram!🍦
# ==================================================
#
# 📋 메뉴판
#
# 1. 초코
# 2. 바닐라
# 3. 딸기
# 4. 우유
# 5. 말차
# 6. 민트초코
# >>>
# 원하시는 메뉴를 선택해주세요. (1~6, 0:처음으로):  3
# --------------------------------------------------
#
# 🍨 사이즈 및 가격
#
# 1. 사이즈: S, 가격: 2,000원
# 2. 사이즈: M, 가격: 3,000원
# 3. 사이즈: L, 가격: 4,000원
# >>>
# 원하시는 사이즈를 선택해주세요. (1~3, 0:뒤로가기):  3
# >>>🤟 원하시는 개수를 적어주세요 (0:뒤로가기):  1234567890
# 10 이하 숫자를 입력하세요.
# >>>🤟 원하시는 개수를 적어주세요 (0:뒤로가기):  9
# --------------------------------------------------
#
# 🍦 장바구니에 추가되었습니다! 🍦
#
# 🛒 현재 장바구니:
# 1. 딸기 (L) x 9개 - 36,000원
# 총 합계: 36,000원
# >>>
# 1. 계속 쇼핑하기  2. 장바구니 보기 및 결제  3. 장바구니에서 상품 삭제  0. 종료
# 선택:  0
# 이용해주셔서 감사합니다! 좋은 하루 되세요! 👋
# >>>
# 1. 계속 쇼핑하기  2. 장바구니 보기 및 결제  3. 장바구니에서 상품 삭제  0. 종료
# 선택:  2
# 🛒 현재 장바구니:
# 1. 딸기 (L) x 9개 - 36,000원
# 총 합계: 36,000원
# >>>1. 결제하기  2. 계속 쇼핑하기  0:  1
# 총 결제 금액: 36,000원
# >>>결제하시겠습니까? (yes/no):  (yes/no):  y
# ⚠️  'yes' 또는 'no'만 입력할 수 있어요.
# >>>결제하시겠습니까? (yes/no):  (yes/no):  yes
# 멤버십을 적립하시겠습니까? (yes/no):  no
# 멤버십 적립을 건너뜁니다.
#
# 결제가 완료되었습니다. 감사합니다! 🍦
#
# ==================================================
#         보고싶었어요! I Miss You Cram!🍦
# ==================================================
#
# 📋 메뉴판
#
# 1. 초코
# 2. 바닐라
# 3. 딸기
# 4. 우유
# 5. 말차
# 6. 민트초코
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 224
#     221     function_1()
#     223 # main
# --> 224 start()
#
# Cell In[19], line 221, in start()
#     219 print(f'        보고싶었어요! {store_name}')
#     220 print('=' * 50)
# --> 221 function_1()
#
# Cell In[19], line 213, in function_1()
#     211 cart['user_menu'] = menu_list[menu_index - 1]
#     212 print('-' * 50)
# --> 213 function_2()
#     214 return
#
# Cell In[19], line 189, in function_2()
#     187         break
#     188 print('-' * 50)
# --> 189 function_3()
#
# Cell In[19], line 149, in function_3()
#     147     return
#     148 elif choice == 2:
# --> 149     function5()
#     150     return
#     151 elif choice == 3:
#
# Cell In[19], line 100, in function5()
#      98     print("결제가 완료되었습니다. 감사합니다! 🍦\n")
#      99     cart_list.clear()
# --> 100     start()
#     101     return
#     103 elif choice == 2:
#
# Cell In[19], line 221, in start()
#     219 print(f'        보고싶었어요! {store_name}')
#     220 print('=' * 50)
# --> 221 function_1()
#
# Cell In[19], line 200, in function_1()
#     197     print(f'{index + 1}. {name}')
#     199 menu_mul = f"\n원하시는 메뉴를 선택해주세요. (1~{len(menu_list)}, 0:처음으로): "
# --> 200 menu_index = get_valid_number_input(menu_mul, 0, len(menu_list))  # 예외처리
#     202 if menu_index is None:
#     203     continue  # None일 경우 아무 처리 없이 다시 메뉴 선택
#
# Cell In[19], line 16, in get_valid_number_input(msg, min_no, max_no)
#      14 def get_valid_number_input(msg, min_no=0, max_no=5):
#      15     try:
# ---> 16         number = int(input('>>>' + msg).strip())
#      17         if number < min_no:
#      18             print(f'{min_no} 이상 숫자를 입력하세요.')
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import datetime

# 전역 변수 선언 (공통 사용)
store_name = '또!젤라또'

menu_list = [
    {'name':'또젤라또','count':'1가지맛', 'price':3000},
    {'name':'또또젤라또','count':'2가지맛', 'price':5000},
    {'name':'또또또젤라또','count':'3가지맛', 'price':7000}
]

flavor_list = [
    {'flavor':'달콤초코봄바람'},
    {'flavor':'새콤달콤딸기정원'},
    {'flavor':'요거트빛파도'},
    {'flavor':'말차소풍'},
    {'flavor':'체리팝송'},
    {'flavor':'포도에몽'},
    {'flavor':'바닐라하모니'},
    {'flavor':'쿠키크러쉬'},
    {'flavor':'소금바다우유'},
    {'flavor':'블루베리썸머'},
    {'flavor':'스윗피치'},
    {'flavor':'레몬샤워'},
]

point_list = []
all_orders = []

# ================= 함수 정의 =================

def select_menu():
    """
    메뉴를 선택하는 함수.
    선택된 메뉴 인덱스를 반환.
    """
    print("="*45)
    print(f'{store_name:^40}')
    print("="*45)
    print("어서오세요 아이스크림을 또 주는 또젤라또입니다\n")

    for i, menu in enumerate(menu_list):
        print(f'{i + 1}. {menu["name"]:<6} {menu["count"]:>12} {menu["price"]:>10,}원')
    print("="*45)

    order_input = input('주문할 메뉴 번호를 입력해주세요: ').strip().lower()

    if not order_input.isdigit() or not (1 <= int(order_input) <= len(menu_list)):
        print("잘못된 입력입니다. 다시 시도해주세요.\n")
        return None

    return int(order_input) - 1

def select_flavors(selected_menu):
    """
    맛 선택 함수
    선택한 메뉴에 따라 선택해야 하는 맛의 개수만큼 입력을 받음

    Args:
        selected_menu (dict): 사용자가 선택한 메뉴 정보 (name, count, price 포함)

    Returns:
        list[str] | None: 선택된 맛 리스트 (정상 선택), 0 입력 시 None 반환
    """
    flavor_count = int(selected_menu['count'][0])
    print(f"\n'{selected_menu['name']}' 선택 — {flavor_count}가지 맛을 골라주세요")

    cols_per_row = 3
    for i, fla in enumerate(flavor_list):
        print(f"{i+1}. {fla['flavor']:<10}", end='')
        if (i + 1) % cols_per_row == 0 or i == len(flavor_list) - 1:
            print()

    flavor_input = input("\n맛 번호들을 입력하세요 (예: 1, 3, 5) / 0 입력시 메뉴 선택으로 돌아가기: ").strip()

    if flavor_input == '0':
        print("맛 선택을 취소하고 메뉴로 돌아갑니다.\n")
        return None  # flavor_canceled 대신 None 반환

    parts = flavor_input.split(',')
    flavor_nums = [int(p.strip()) - 1 for p in parts if p.strip().isdigit()]

    if len(flavor_nums) != flavor_count or any(i < 0 or i >= len(flavor_list) for i in flavor_nums):
        print(f"정확히 {flavor_count}가지 맛을 정확히 입력해주세요.")
        return []

    selected_flavors = [flavor_list[i]['flavor'] for i in flavor_nums]
    return selected_flavors


def cart(orders, selected_menu, selected_flavors):
    """
    주문 확인 및 장바구니 추가 함수
    현재 선택한 메뉴와 맛을 출력하고 사용자에게 장바구니 추가 여부를 확인

    Args:
        orders (list): 현재 주문 목록 리스트 (dict 요소)
        selected_menu (dict): 선택된 메뉴 정보
        selected_flavors (list): 선택된 맛 리스트

    Returns:
        bool: 장바구니에 추가(True), 취소(False)
    """
    print("\n선택한 주문:")
    print(f"메뉴: {selected_menu['name']}") # 선택한 메뉴(사이즈) 
    for idx, name in enumerate(selected_flavors):
        print(f" - 맛 {idx+1}: {name}") #맛 순번과 맛이름
    print(f"가격: {selected_menu['price']:,}원") #총 가격

    while True:
        confirm = input("\n이 주문을 장바구니에 추가할까요? (Y: 추가 / N: 취소): ").strip().lower()
        if confirm == 'y':               
            orders.append({
                'menu_name': selected_menu['name'],
                'flavor_names': selected_flavors,
                'price': selected_menu['price']
            })
            print("주문이 장바구니에 추가되었습니다.\n")
            return True
        elif confirm == 'n':
            print("주문이 취소되었습니다.\n")
            return False
        else:
            print('!(Y/N)로 입력해주세요!')


def extra_order():
    """
    추가 주문 여부 확인 함수

    Returns:
        bool: 추가 주문할 경우 True, 아니면 False
    """   
    while True:
        another = input("추가 주문하시겠습니까? (Y/N): ").strip().lower()
        if another == 'y':
            return True  # 다시 메뉴 선택으로
        elif another == 'n':
            return False  # 주문 확인 단계로
        else:
            print('!(Y/N)로 입력해주세요!')

def show_orders(orders):
    """
    현재 주문 내역 출력 함수

    Args:
        orders (list): 주문 내역 리스트 (dict 요소)
    """
    
    if not orders:
        print("현재 주문이 없습니다.")

    else:
        for i, order in enumerate(orders):
            print(f"{i+1}. {order['menu_name']} — {order['price']:,}원")
            for idx, name in enumerate(order['flavor_names']):
                print(f"   - 맛 {idx+1}: {name}")


def canceled(orders):
    """
    주문 취소 처리 함수
    주문 내역을 출력하고 사용자가 취소를 원하는 주문을 삭제할 수 있게 함

    Args:
        orders (list): 현재 주문 내역 리스트

    Returns:
        bool: 남은 주문이 있으면 False (결제 진행) 없으면 True (처음으로 돌아감)
    """
    while True:
        if not orders:
            print("현재 주문이 없습니다.")
            return True
            
        cancel_q = input("\n주문 내역 중 취소할 주문이 있습니까? (Y/N): ").strip().lower()
        if cancel_q == 'n':
            return False # 취소 안 하고 결제 진행
        elif cancel_q == 'y':
            print("\n다시 주문 내역을 보여드립니다:")
            for i, order in enumerate(orders):
                print(f"{i+1}. {order['menu_name']} — {order['price']:,}원")
                for idx, name in enumerate(order['flavor_names']):
                    print(f"   - 맛 {idx+1}: {name}")

            del_input = input("취소할 주문 번호를 입력하세요 (0 입력시 결제창으로): ").strip()
            if del_input == '0':
                return False # 결제 진행
            if del_input.isdigit() and 1 <= int(del_input) <= len(orders):
                del_index = int(del_input) - 1
                removed = orders.pop(del_index)
                print(f"'{removed['menu_name']}' 주문이 삭제되었습니다.")
            else:
                print("잘못된 번호입니다.")
        else:
            print("!(Y/N)로 입력해주세요!")


def check_out(orders):
    """
    최종 결제 금액 계산 함수

    Args:
        orders (list): 현재 주문 내역 리스트

    Returns:
        int: 총 결제 금액
    """
    print("\n💳 최종 주문 내역:")
    for i, order in enumerate(orders):
        print(f"{i+1}. {order['menu_name']} — {order['price']:,}원")
        for idx, name in enumerate(order['flavor_names']):
            print(f"   - 맛 {idx+1}: {name}")
    
    total_price = sum(order['price'] for order in orders)
    print('\n' + '='*45)
    print(f"💰 총 결제 금액: {total_price:,}원")
    return total_price


def member_ship(point_list, total_price):
    """
    포인트 적립 처리 함수
    전화번호로 적립 또는 신규 등록

    Args:
        point_list (list): 포인트 정보 저장 리스트
        total_price (int): 총 결제 금액

    Returns:
        str: 전화번호 (회원), 또는 "고객"
    """
    while True:
        point_q = input('포인트 적립하시겠습니까? (Y/N): ').strip().lower()
        if point_q == 'y':
            membership = input("전화번호를 입력해주세요: ").strip()
            saved_point = total_price // 100
            idx = -1
            
            for i, user in enumerate(point_list):
                if user['membership_nb'] == membership:
                    idx = i
                    break
                    
            if idx != -1:
                point_list[idx]['membership_point'] += saved_point
                total_point = point_list[idx]['membership_point']
            else:
                point_list.append({'membership_nb': membership, 'membership_point': saved_point})
                total_point = saved_point
                
            print(f"{saved_point}포인트 적립 완료 → 총 {total_point}포인트")
            return membership  # ✅ 함수 반환으로 name 대체
            
        elif point_q == 'n':
            return "고객"
        else:
            print('!(Y/N)로 입력해주세요!')
# 메인 루프

while True:
    orders = []
    while True:
        order_num = select_menu()
        if order_num is None:
            continue
        selected_menu = menu_list[order_num]

        selected_flavors = select_flavors(selected_menu)
        if selected_flavors is None:
            continue
        elif not selected_flavors:
            continue

        if not cart(orders, selected_menu, selected_flavors):
            continue

        if not extra_order():
            break  # 주문 루프 종료

    if canceled(orders):
        continue  # 결제 전 주문 모두 취소된 경우 -> 처음부터

    total_price = check_out(orders)
    if total_price == 0:
        print("남은 주문이 없습니다. 처음으로 돌아갑니다.\n")
        continue

    name = member_ship(point_list, total_price)

    now = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    all_orders.append({
        'timestamp': now,
        'orders': orders.copy(),
        'total_price': total_price
    })

    print(f"\n{name}님, 주문 감사합니다! 또 오세요.")
    print("=" * 45)
# Out:
# =============================================
#                  또!젤라또
# =============================================
# 어서오세요 아이스크림을 또 주는 또젤라또입니다
#
# 1. 또젤라또           1가지맛      3,000원
# 2. 또또젤라또          2가지맛      5,000원
# 3. 또또또젤라또         3가지맛      7,000원
# =============================================
# 주문할 메뉴 번호를 입력해주세요:  3
# '또또또젤라또' 선택 — 3가지 맛을 골라주세요
# 1. 달콤초코봄바람   2. 새콤달콤딸기정원  3. 요거트빛파도
# 4. 말차소풍      5. 체리팝송      6. 포도에몽
# 7. 바닐라하모니    8. 쿠키크러쉬     9. 소금바다우유
# 10. 블루베리썸머    11. 스윗피치      12. 레몬샤워
# 맛 번호들을 입력하세요 (예: 1, 3, 5) / 0 입력시 메뉴 선택으로 돌아가기:  1,2,3
# 선택한 주문:
# 메뉴: 또또또젤라또
#  - 맛 1: 달콤초코봄바람
#  - 맛 2: 새콤달콤딸기정원
#  - 맛 3: 요거트빛파도
# 가격: 7,000원
# 이 주문을 장바구니에 추가할까요? (Y: 추가 / N: 취소):  y
# 주문이 장바구니에 추가되었습니다.
# 추가 주문하시겠습니까? (Y/N):  y
# =============================================
#                  또!젤라또
# =============================================
# 어서오세요 아이스크림을 또 주는 또젤라또입니다
#
# 1. 또젤라또           1가지맛      3,000원
# 2. 또또젤라또          2가지맛      5,000원
# 3. 또또또젤라또         3가지맛      7,000원
# =============================================
# 주문할 메뉴 번호를 입력해주세요:  3
# '또또또젤라또' 선택 — 3가지 맛을 골라주세요
# 1. 달콤초코봄바람   2. 새콤달콤딸기정원  3. 요거트빛파도
# 4. 말차소풍      5. 체리팝송      6. 포도에몽
# 7. 바닐라하모니    8. 쿠키크러쉬     9. 소금바다우유
# 10. 블루베리썸머    11. 스윗피치      12. 레몬샤워
# 맛 번호들을 입력하세요 (예: 1, 3, 5) / 0 입력시 메뉴 선택으로 돌아가기:  4,6,9
# 선택한 주문:
# 메뉴: 또또또젤라또
#  - 맛 1: 말차소풍
#  - 맛 2: 포도에몽
#  - 맛 3: 소금바다우유
# 가격: 7,000원
# 이 주문을 장바구니에 추가할까요? (Y: 추가 / N: 취소):  y
# 주문이 장바구니에 추가되었습니다.
# 추가 주문하시겠습니까? (Y/N):  n
#
# 주문 내역 중 취소할 주문이 있습니까? (Y/N):  n
# 💳 최종 주문 내역:
# 1. 또또또젤라또 — 7,000원
#    - 맛 1: 달콤초코봄바람
#    - 맛 2: 새콤달콤딸기정원
#    - 맛 3: 요거트빛파도
# 2. 또또또젤라또 — 7,000원
#    - 맛 1: 말차소풍
#    - 맛 2: 포도에몽
#    - 맛 3: 소금바다우유
#
# =============================================
# 💰 총 결제 금액: 14,000원
# 포인트 적립하시겠습니까? (Y/N):  y
# 전화번호를 입력해주세요:  56
# 140포인트 적립 완료 → 총 140포인트
#
# 56님, 주문 감사합니다! 또 오세요.
# =============================================
# =============================================
#                  또!젤라또
# =============================================
# 어서오세요 아이스크림을 또 주는 또젤라또입니다
#
# 1. 또젤라또           1가지맛      3,000원
# 2. 또또젤라또          2가지맛      5,000원
# 3. 또또또젤라또         3가지맛      7,000원
# =============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 265
#     263 orders = []
#     264 while True:
# --> 265     order_num = select_menu()
#     266     if order_num is None:
#     267         continue
#
# Cell In[1], line 46, in select_menu()
#      43     print(f'{i + 1}. {menu["name"]:<6} {menu["count"]:>12} {menu["price"]:>10,}원')
#      44 print("="*45)
# ---> 46 order_input = input('주문할 메뉴 번호를 입력해주세요: ').strip().lower()
#      48 if not order_input.isdigit() or not (1 <= int(order_input) <= len(menu_list)):
#      49     print("잘못된 입력입니다. 다시 시도해주세요.\n")
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Finalised ver

# %%
import time
points = {}
# # 메뉴 저장 리스트 -> 메뉴 추가 시 여기서.
menu = [
    {'name':'샤프', 'price': 6000},
    {'name':'볼펜', 'price': 3000},
    {'name':'지우개', 'price': 1000},
    {'name':'화이트', 'price': 3000},
    {'name':'공책', 'price': 3500}
]

def prt_menu(menu):
    print('╔' + '═' * 40 + '╗')
    print(f'빵꾸똥꾸 문구야'.center(34))
    print(f"에 오신 것을 환영합니다!💥".center(34))
    print('╚' + '═' * 40 + '╝') 
    print(f'{"번호"}\t\t{"제품명"}\t\t{"가격"}')
    print('-'*44)

    for i, m in enumerate(menu):
        print(f'{i+1}\t\t{m["name"]}\t\t{m["price"]:,}원')
    print('-'*44)

def prt_alarm():
    print('='*44)
    print(f'{"[알림]❌ 잘못된 입력입니다.":^35}')
    print(f'{"[알림]✅ 다시 입력해주세요.":^35}')
    print('='*44)

def prt_time():
    for i in range(3, 0, -1):
        print('=' * 44)
        print(f'{i}초 뒤에 시작화면으로 돌아갑니다.'.center(34))
        time.sleep(1)
        
def add_ord():
    while True:        
        try:
            ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
            if not (0 <= ord_num < len(menu)):
                prt_alarm()
                continue
            return ord_num
        except ValueError:
            prt_alarm()
            continue
        
def add_qty():
    while True:
        qty = input('\t수량을 입력하세요(취소: x): ')
        if qty.lower() =="x":
            return qty
        try:
            qty = int(qty)
            if qty > 0:
                return qty
            prt_alarm()
        except ValueError:
            prt_alarm()

def add_lst(order_list, ord_num, qty):
    item = menu[ord_num]
    for i in order_list:
        if i['name'] == item['name']:
            i['qty'] += qty
            return order_list 
    order_list.append({
        'name': item['name'],
        'qty': qty,
        'price': item['price']
    })
    return order_list
    
def yesno():
    while True:
        a=input('더 주문하시겠습니까?(y/n):')
        if a.lower() not in ['y','n']:
            prt_alarm()
            continue
        else:
            return a
            
def calc_cost():
    total = 0   
    print('='*44)
    print(f'\t\t{"주문 내역"}')
    print('-'*44)

    for order in order_list:
        item_total = order['qty'] * order['price']
        total += item_total

        print(f'{order["name"]}\t{order["qty"]}개\t-\t{item_total:,}원')

    print('-'*44)
    print(f'총 결제 금액: {total:,}원')
    print('='*44)
    return total

def prt_points():
    while True:
        ab = input('포인트를 적립하시겠습니까? (y/n): ')
        if ab.lower() not in ['y', 'n']:
            prt_alarm()
            continue
        elif ab.lower()=='n':
            return        
        else:
            while True:
                phone = input('전화번호를 입력해 주세요: ')
                if not phone.isdigit() or len(phone) < 11 or phone == "x":
                    prt_alarm()
                    continue                       
                user_id = f'user_{phone[-4:]}'
                point = int(total * 0.05)                 
                if user_id in points :
                    points[user_id] += point
                else :
                    points[user_id] = point
                print('='*44)
                print(f'🎁{user_id}고객님, {point}점 적립 되었습니다!🎁')
                print(f' 고객님의 총 적립포인트는 {points[user_id]:,}점 입니다!')
                print('='*44)
                return
     
######################################################################################################################################################


def draw_pencil_ascii():
    pencil_art = r"""
        .================ooooooo
 ___   ,'    \_________________________________
/   /-/       /                   ////////////  ''--..._
\___\-\       \                   \\\\\\\\\\\\  __..--'
       `--------------------------''''''''''''''
"""
    print(pencil_art)

draw_pencil_ascii()

while True:
    prt_menu(menu)
    # 다중 주문 저장 리스트
    order_list = []

    while True: 
        
        ord_num = add_ord()         
        menut = menu[ord_num]['name']
        
        print('='*44)
        print(f'{"고객님이 선택하신 제품은":^33}')
        print(f'{menut + " 입니다.":^33}')
        print(f'{"몇 개를 드릴까요?":^33}')
        
        
        qty = add_qty()
        if qty in ('x','X'):
            break
             
        add_lst(order_list, ord_num, qty)
        
        answer = yesno()
        if answer == 'n':
            break
        print('-'*44)

    if qty not in ('x','X'):
        
        total = calc_cost()
        
        prt_points()
        
        print(f'{"결제가 완료되었습니다.":^37}')
        print(f'{"잠시만 기다려주세요. 😊":^37}')

        prt_time()
# Out:
#         .================ooooooo
#  ___   ,'    \_________________________________
# /   /-/       /                   ////////////  ''--..._
# \___\-\       \                   \\\\\\\\\\\\  __..--'
#        `--------------------------''''''''''''''
#
# ╔════════════════════════════════════════╗
#              빵꾸똥꾸 문구야
#          에 오신 것을 환영합니다!💥
# ╚════════════════════════════════════════╝
# 번호		제품명		가격
# --------------------------------------------
# 1		샤프		6,000원
# 2		볼펜		3,000원
# 3		지우개		1,000원
# 4		화이트		3,000원
# 5		공책		3,500원
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 147
#     143 order_list = []
#     145 while True:
# --> 147     ord_num = add_ord()
#     148     menut = menu[ord_num]['name']
#     150     print('='*44)
#
# Cell In[1], line 39, in add_ord()
#      37 while True:
#      38     try:
# ---> 39         ord_num = int(input('주문하실 제품 번호를 선택하세요: ')) -1
#      40         if not (0 <= ord_num < len(menu)):
#      41             prt_alarm()
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # 연습

# %%
class QtyException(Exception):
    def __init__(self,msg):
        self._message=msg

def input_qty():
    qty=int(input('수량을 입력하세요: '))

    if qty<0:
        raise QtyException('수량은 양수입니다')
    elif qty>10000:
        raise QtyException('확실해요??')
    else: 
        return qty

# %%
try:
    qty=input_qty()
except QtyException as q:
    print (q.args[0])
else:
    print(f'입력하신 수량은 {qty}입니다')
# Out:
# 수량을 입력하세요:  1123456789
# 확실해요??

# %%
class yesno(Exception):
    def __init__(self,msg):
        self._message=msg

def input_ans():
    ans=int(input('더 주문하시겠습니까?(y/n):'))

    if ans not in ['y','n','Y','N']:
        raise yesno(prt_alarm())
    return ans

def prt_alarm():
    print('='*44)
    print(f'{"[알림]❌ 잘못된 입력입니다.":^35}')
    print(f'{"[알림]✅ 다시 입력해주세요.":^35}')
    print('='*44)

# %%
class YesNoError(Exception):
    def __init__(self, msg):
        self._message = msg
    def __str__(self):
        return self._message

def input_ans():
    try:
        ans = input('더 주문하시겠습니까? (y/n): ').lower()
        if ans not in ['y', 'n']:
            raise YesNoError("[알림]❌ 잘못된 입력입니다.\n[알림]✅ 다시 입력해주세요.")
        return ans
    except YesNoError as e:
        print(e)
        return input_ans()

# %%
input_ans()
# Out:
# 더 주문하시겠습니까? (y/n):  u
# [알림]❌ 잘못된 입력입니다.
# [알림]✅ 다시 입력해주세요.
# 더 주문하시겠습니까? (y/n):  y
# 'y'

# %%
|
